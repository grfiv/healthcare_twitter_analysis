# %% [markdown]
# Online Twitter Basics
# ======================

# %% [markdown]
# ###This notebook gives a summary of the basics of getting onto Twitter, live, and navigating around.
#
# My thanks to Bill Howe of the University of Washington for his Coursera course *Introduction to Data Analysis* and Matthew A. Russell for his book *Mining the Social Web* for getting me started.
#
# Note 1: I run the IPython notebook in pylab=inline mode which makes it look like Matlab; this may mean that you will have to explicitly `import` some modules that I take for granted. Alternatively, you could configure yourself for pylab, which I obviously think is better.
#
# Note 2: Twitter is more popular outside the United States than within. Many non-English languages have codesets that I don't handle properly leading to program failures. Keep calm and carry on: usually a restart will be all that's needed.

# %% [markdown]
# ### Logon to Twitter

# %% [markdown]
# I have my Twitter credentials in a file `twitter_credential.py`; you need to create your own as follows:
# ```python
# def twitter_credentials():
#     """
#     Generate your own Twitter credentials here:  https://apps.twitter.com/
#     """
#     api_key = " "
#     api_secret = " "
#
#     access_token_key = " "
#     access_token_secret = " "
#
#     return (api_key, api_secret, access_token_key, access_token_secret)
# ```
# If you get a message similar to `<twitter.api.Twitter object at 0x000000000E79AAC8>`, you've succesfully signed on

# %%
from twitter_credentials import twitter_credentials # my credentials
token, token_secret, consumer_key, consumer_secret = twitter_credentials()

import oauth2 as oauth
import urllib2 as urllib
import twitter

auth = twitter.oauth.OAuth(consumer_key, consumer_secret, token, token_secret)

twitter_api = twitter.Twitter(auth=auth)
print twitter_api
# Out:
# <twitter.api.Twitter object at 0x0000000010898B38>

# %% [markdown]
# ###QT Console
# I like to run the qtconsole whenever I am using a notebook because it allows me to experiment on a command-line interface to the notebook's session, with all its current variables, etc.

# %%
# %qtconsole

# %% [markdown]
# ###`twitter_functions.py`
# I have a file `twitter_functions.py` that contains a number of utility functions. A more-or-less current version of it is on my GitHub repo: [grfiv/healthcare_twitter_analysis](https://github.com/grfiv/healthcare_twitter_analysis)
#
# You also need to have the `AFINN-111.txt` sentiment-word file installed.

# %% [markdown]
# ### Make a simple query

# %%
import json
from twitter_functions import twitter_search

num_tweet_request = 250

q = "Melanoma"
initial_results = twitter_search(twitter_api, q, max_results = num_tweet_request)

# %% [markdown]
# ### Filter by `retweet_count`

# %% [markdown]
# The idea is that the the best tweets are ones that have been retweeted. So we will keep only those tweets of the ones that have a `retweet_count` greater than some threshold.
#
# `favorite_count` is also supposed to have some bearing on importance but it's usually zero in the ones I've looked at. I list it below and you can judge for yourself.

# %%
retweet_threshold = 3

results = [tweet 
           for tweet in initial_results 
           if tweet['retweet_count'] > retweet_threshold]

num_tweets = len(results)
print "%d tweets received"%len(initial_results)
print "%d tweets after retweet filtering"%len(results)
# Out:
# 300 tweets received
# 47 tweets after retweet filtering

# %% [markdown]
# ### Display the raw json returned for one of the `num_tweets` results we asked for

# %%
# I commented this out because the list is very long
# However, to do any serious Twitter munging, you need to know all about this thing

#print json.dumps(results[1], indent=4)
# Out:
# {
#     "contributors": null,
#     "truncated": false,
#     "text": "RT @_SEOM: En verano, cuida tu piel, prot\u00e9gete del sol. Prevenci\u00f3n del #Cancer http://t.co/h8oDXIbrGj",
#     "in_reply_to_status_id": null,
#     "id": 488840351336382466,
#     "favorite_count": 0,
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "retweeted": false,
#     "coordinates": null,
#     "entities": {
#         "symbols": [],
#         "user_mentions": [
#             {
#                 "id": 555051765,
#                 "indices": [
#                     3,
#                     9
#                 ],
#                 "id_str": "555051765",
#                 "screen_name": "_SEOM",
#                 "name": "SEOM"
#             }
#         ],
#         "hashtags": [
#             {
#                 "indices": [
#                     71,
#                     78
#                 ],
#                 "text": "Cancer"
#             }
#         ],
#         "urls": [
#             {
#                 "url": "http://t.co/h8oDXIbrGj",
#                 "indices": [
#                     79,
#                     101
#                 ],
#                 "expanded_url": "http://www.seom.org/es/notas-prensa/104754-seom-advierte-el-melanoma-en-espana-se-ha-multiplicado-por-10-en-los-ultimos-20-anos-y-es-la-causa-del-65-de-las-muertes-por-cancer-cutaneo",
#                 "display_url": "seom.org/es/notas-prens\u2026"
#             }
#         ]
#     },
#     "in_reply_to_screen_name": null,
#     "in_reply_to_user_id": null,
#     "retweet_count": 4,
#     "id_str": "488840351336382466",
#     "favorited": false,
#     "retweeted_status": {
#         "contributors": null,
#         "truncated": false,
#         "text": "En verano, cuida tu piel, prot\u00e9gete del sol. Prevenci\u00f3n del #Cancer http://t.co/h8oDXIbrGj",
#         "in_reply_to_status_id": null,
#         "id": 488601154805194753,
#         "favorite_count": 1,
#         "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#         "retweeted": false,
#         "coordinates": null,
#         "entities": {
#             "symbols": [],
#             "user_mentions": [],
#             "hashtags": [
#                 {
#                     "indices": [
#                         60,
#                         67
#                     ],
#                     "text": "Cancer"
#                 }
#             ],
#             "urls": [
#                 {
#                     "url": "http://t.co/h8oDXIbrGj",
#                     "indices": [
#                         68,
#                         90
#                     ],
#                     "expanded_url": "http://www.seom.org/es/notas-prensa/104754-seom-advierte-el-melanoma-en-espana-se-ha-multiplicado-por-10-en-los-ultimos-20-anos-y-es-la-causa-del-65-de-las-muertes-por-cancer-cutaneo",
#                     "display_url": "seom.org/es/notas-prens\u2026"
#                 }
#             ]
#         },
#         "in_reply_to_screen_name": null,
#         "in_reply_to_user_id": null,
#         "retweet_count": 4,
#         "id_str": "488601154805194753",
#         "favorited": false,
#         "user": {
#             "follow_request_sent": false,
#             "profile_use_background_image": true,
#             "default_profile_image": false,
#             "id": 555051765,
#             "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/782774893/99a469219d6d38c9f9ba1818cb6c2faf.jpeg",
#             "verified": false,
#             "profile_text_color": "333333",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/485046201876623362/GV-q-tGu_normal.jpeg",
#             "profile_sidebar_fill_color": "DDFFCC",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "http://t.co/z1QEcRVw9C",
#                             "indices": [
#                                 0,
#                                 22
#                             ],
#                             "expanded_url": "http://www.seom.org",
#                             "display_url": "seom.org"
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": [
#                         {
#                             "url": "http://t.co/Sm8ehHiojX",
#                             "indices": [
#                                 129,
#                                 151
#                             ],
#                             "expanded_url": "http://www.oncosaludable.es",
#                             "display_url": "oncosaludable.es"
#                         }
#                     ]
#                 }
#             },
#             "followers_count": 5660,
#             "profile_sidebar_border_color": "FFFFFF",
#             "id_str": "555051765",
#             "profile_background_color": "99C6C9",
#             "listed_count": 190,
#             "is_translation_enabled": false,
#             "utc_offset": 7200,
#             "statuses_count": 6848,
#             "description": "Twitter oficial de la Sociedad Espa\u00f1ola de Oncolog\u00eda M\u00e9dica.\r\nDocencia,asistencia,investigaci\u00f3n en c\u00e1ncer y apoyo al paciente\r\n\r\nhttp://t.co/Sm8ehHiojX",
#             "friends_count": 1084,
#             "location": "",
#             "profile_link_color": "007078",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/485046201876623362/GV-q-tGu_normal.jpeg",
#             "following": false,
#             "geo_enabled": false,
#             "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/782774893/99a469219d6d38c9f9ba1818cb6c2faf.jpeg",
#             "screen_name": "_SEOM",
#             "lang": "es",
#             "profile_background_tile": false,
#             "favourites_count": 19,
#             "name": "SEOM",
#             "notifications": false,
#             "url": "http://t.co/z1QEcRVw9C",
#             "created_at": "Mon Apr 16 08:38:44 +0000 2012",
#             "contributors_enabled": false,
#             "time_zone": "Madrid",
#             "protected": false,
#             "default_profile": false,
#             "is_translator": false
#         },
#         "geo": null,
#         "in_reply_to_user_id_str": null,
#         "possibly_sensitive": false,
#         "lang": "es",
#         "created_at": "Mon Jul 14 08:29:27 +0000 2014",
#         "in_reply_to_status_id_str": null,
#         "place": null,
#         "metadata": {
#             "iso_language_code": "es",
#             "result_type": "recent"
#         }
#     },
#     "user": {
#         "follow_request_sent": false,
#         "profile_use_background_image": true,
#         "default_profile_image": false,
#         "id": 133299828,
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "verified": false,
#         "profile_text_color": "333333",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1803947859/IMGP5627_crop_normal.jpg",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "followers_count": 38,
#         "profile_sidebar_border_color": "C0DEED",
#         "id_str": "133299828",
#         "profile_background_color": "C0DEED",
#         "listed_count": 1,
#         "is_translation_enabled": false,
#         "utc_offset": 7200,
#         "statuses_count": 459,
#         "description": "Yokona de Yoko",
#         "friends_count": 46,
#         "location": "",
#         "profile_link_color": "0084B4",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1803947859/IMGP5627_crop_normal.jpg",
#         "following": false,
#         "geo_enabled": false,
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "screen_name": "yokona_2",
#         "lang": "es",
#         "profile_background_tile": false,
#         "favourites_count": 10,
#         "name": "yolanda borrego",
#         "notifications": false,
#         "url": null,
#         "created_at": "Thu Apr 15 13:46:10 +0000 2010",
#         "contributors_enabled": false,
#         "time_zone": "Amsterdam",
#         "protected": false,
#         "default_profile": true,
#         "is_translator": false
#     },
#     "geo": null,
#     "in_reply_to_user_id_str": null,
#     "possibly_sensitive": true,
#     "lang": "es",
#     "created_at": "Tue Jul 15 00:19:56 +0000 2014",
#     "in_reply_to_status_id_str": null,
#     "place": null,
#     "metadata": {
#         "iso_language_code": "es",
#         "result_type": "recent"
#     }
# }

# %% [markdown]
# ###Parse the 'text' field, which is the body of the tweet, for each of the `num_tweets` responses returned
# It's obviously possible to parse the json directly, but for this particular task my utility function is way easier and it provides the AFINN-111 sentiment value, too. (For which you must have the `AFINN-111.txt` file installed.)
#
# A response of `[]` means nothing was returned for a particular 'entity'.

# %%
from twitter_functions import parse_tweet_text 

for i in range(num_tweets):
    tweet_text = results[i]['text']
    words, hashes, users, urls, AFINN_score = parse_tweet_text(tweet_text, AFINN=True)

    print "the actual text of results[%d]['text']\nretweet_count = %d\nfavorite_count = %d\n...................\n%s"%(i,results[i]['retweet_count'],results[i]['favorite_count'],tweet_text)
    print "\nthe list of words %s"%[word.encode('utf-8') for word in words]
    print "all hashtags referenced %s"%[hash_.encode('utf-8') for hash_ in hashes]
    print "all twitter users mentioned %s"%[user.encode('utf-8') for user in users]
    print "all URLs %s"%[url.encode('utf-8') for url in urls]
    print "AFINN sentiment score %d"%AFINN_score
    print "............................"
    print "description: %s"%results[i]['user']['description']
    print "followers_count: %d"%results[i]['user']['followers_count']
    print "friends_count: %d"%results[i]['user']['friends_count']
    print "favourites_count: %d"%results[i]['user']['favourites_count']
    print "location: %s"%results[i]['user']['location']
    print "time_zone: %s"%results[i]['user']['time_zone']
    print "screen_name: %s"%results[i]['user']['screen_name']
    print "name: %s"%results[i]['user']['name']
    if results[i]['place'] is not None: print "place: %s"%results[i]['place']
    print "====================================================================================\n"
# Out:
# the actual text of results[0]['text']
# retweet_count = 22
# favorite_count = 0
# ...................
# RT @Walmart: Join @BowesDerm, @itsgabrielleu &amp; @sandraecheverr now for #ChooseSkinHealth &amp; learn more on melanoma. #Neutrogena http://t.co/…
#
# the list of words ['rt', 'join', 'now', 'for', 'learn', 'more', 'on', 'melanoma.']
# all hashtags referenced ['chooseskinhealth', 'neutrogena']
# all twitter users mentioned ['walmart', 'bowesderm', 'itsgabrielleu', 'sandraecheverr']
# all URLs ['http://t.co/']
# AFINN sentiment score 1
# ............................
# description: Actriz/cantante a soñar muchoooo para materializar los deseos!!!  http://t.co/aQIYxsOtve
# sscher@evolution-ent.com
# followers_count: 772555
# friends_count: 813
# favourites_count: 18
# location: Los Angeles, CA
# time_zone: Pacific Time (US & Canada)
# screen_name: sandraecheverr
# name: Sandra Echeverria
# ====================================================================================
#
# the actual text of results[1]['text']
# retweet_count = 4
# favorite_count = 0
# ...................
# RT @_SEOM: En verano, cuida tu piel, protégete del sol. Prevención del #Cancer http://t.co/h8oDXIbrGj
#
# the list of words ['rt', 'en', 'verano,', 'cuida', 'tu', 'piel,', 'prot\xc3\xa9gete', 'del', 'sol.', 'prevenci\xc3\xb3n', 'del']
# all hashtags referenced ['cancer']
# all twitter users mentioned ['_seom']
# all URLs ['http://t.co/h8odxibrgj']
# AFINN sentiment score 0
# ............................
# description: Yokona de Yoko
# followers_count: 38
# friends_count: 46
# favourites_count: 10
# location:
# time_zone: Amsterdam
# screen_name: yokona_2
# name: yolanda borrego
# ====================================================================================
#
# the actual text of results[2]['text']
# retweet_count = 4
# favorite_count = 0
# ...................
# RT @cancersocietybc: MT @TanningisOut: @CityofVancouver No umbrellas used on Robson? #melanoma is rising, pls bring back shade! http://t.co…
#
# the list of words ['rt', 'mt', 'no', 'umbrellas', 'used', 'on', 'robson?', 'is', 'rising,', 'pls', 'bring', 'back', 'shade!']
# all hashtags referenced ['melanoma']
# all twitter users mentioned ['cancersocietybc', 'tanningisout', 'cityofvancouver']
# all URLs ['http://t.co']
# AFINN sentiment score -1
# ............................
# description: Student interested in promoting healthy skin and cancer prevention
# followers_count: 192
# friends_count: 91
# favourites_count: 0
# location: Canada
# time_zone: None
# screen_name: skinaware
# name: Skin Aware
# ====================================================================================
#
# the actual text of results[3]['text']
# retweet_count = 5
# favorite_count = 0
# ...................
# RT @acyr11: Tell your kids and friends about the new #melanoma website we developed for youth @screenmeMNC  - totally awesome!
#
# the list of words ['rt', 'tell', 'your', 'kids', 'and', 'friends', 'about', 'the', 'new', 'website', 'we', 'developed', 'for', 'youth', 'totally', 'awesome!']
# all hashtags referenced ['melanoma']
# all twitter users mentioned ['acyr11', 'screenmemnc']
# all URLs []
# AFINN sentiment score 0
# ............................
# description: Living for today. Tomorrow isn't guaranteed. Dog rescuer. Tennis lover. Volleyball player. Independent to a fault. Bilingual: English & sarcasm. Potty mouth.
# followers_count: 94
# friends_count: 333
# favourites_count: 19
# location: Canada
# time_zone: Eastern Time (US & Canada)
# screen_name: Holdensmum
# name: Jennifer
# ====================================================================================
#
# the actual text of results[4]['text']
# retweet_count = 4
# favorite_count = 0
# ...................
# RT @cancersocietybc: MT @TanningisOut: @CityofVancouver No umbrellas used on Robson? #melanoma is rising, pls bring back shade! http://t.co…
#
# the list of words ['rt', 'mt', 'no', 'umbrellas', 'used', 'on', 'robson?', 'is', 'rising,', 'pls', 'bring', 'back', 'shade!']
# all hashtags referenced ['melanoma']
# all twitter users mentioned ['cancersocietybc', 'tanningisout', 'cityofvancouver']
# all URLs ['http://t.co']
# AFINN sentiment score -1
# ............................
# description: Girl Scout Gold Award to educate people about skin cancer and prevention!!!
# followers_count: 113
# friends_count: 102
# favourites_count: 140
# location: Vernon Hills
# time_zone: None
# screen_name: SunSafetyGold
# name: Lisa Breitenfield
# ====================================================================================
#
# the actual text of results[5]['text']
# retweet_count = 4
# favorite_count = 0
# ...................
# RT @cancersocietybc: MT @TanningisOut: @CityofVancouver No umbrellas used on Robson? #melanoma is rising, pls bring back shade! http://t.co…
#
# the list of words ['rt', 'mt', 'no', 'umbrellas', 'used', 'on', 'robson?', 'is', 'rising,', 'pls', 'bring', 'back', 'shade!']
# all hashtags referenced ['melanoma']
# all twitter users mentioned ['cancersocietybc', 'tanningisout', 'cityofvancouver']
# all URLs ['http://t.co']
# AFINN sentiment score -1
# ............................
# description: Spreading the word about #SunSafety, #skincancerawareness, and #melanomaawareness , connecting with one person at a time.
# followers_count: 1143
# friends_count: 1992
# favourites_count: 136
# location: Bay Area, CA
# time_zone: Pacific Time (US & Canada)
# screen_name: canopyvalley
# name: Canopy Valley Team
# ====================================================================================
#
# the actual text of results[6]['text']
# retweet_count = 5
# favorite_count = 0
# ...................
# RT @acyr11: Tell your kids and friends about the new #melanoma website we developed for youth @screenmeMNC  - totally awesome!
#
# the list of words ['rt', 'tell', 'your', 'kids', 'and', 'friends', 'about', 'the', 'new', 'website', 'we', 'developed', 'for', 'youth', 'totally', 'awesome!']
# all hashtags referenced ['melanoma']
# all twitter users mentioned ['acyr11', 'screenmemnc']
# all URLs []
# AFINN sentiment score 0
# ............................
# description: A glass of #wine, some smooth #Jazz, and some random #food creation.  Reading a lot about #skincancer and #melanoma
# followers_count: 322
# friends_count: 2000
# favourites_count: 33
# location:
# time_zone: None
# screen_name: GeeDup997
# name: GeeDup
# ====================================================================================
#
# the actual text of results[7]['text']
# retweet_count = 8
# favorite_count = 0
# ...................
# RT @SherryInk: I've been a #skincancer patient for 9 years #Melanoma #Blog #ItCanHappenToYou #Health #sunsafety http://t.co/qktkJjp1nc
#
# the list of words ['rt', "i've", 'been', 'a', 'patient', 'for', '9', 'years']
# all hashtags referenced ['skincancer', 'melanoma', 'blog', 'itcanhappentoyou', 'health', 'sunsafety']
# all twitter users mentioned ['sherryink']
# all URLs ['http://t.co/qktkjjp1nc']
# AFINN sentiment score 0
# ............................
# description: Film and photography
# followers_count: 4591
# friends_count: 1926
# favourites_count: 28
# location:
# time_zone: None
# screen_name: Curtisimage
# name: Curtis
# ====================================================================================
#
# the actual text of results[8]['text']
# retweet_count = 5
# favorite_count = 0
# ...................
# RT @acyr11: Tell your kids and friends about the new #melanoma website we developed for youth @screenmeMNC  - totally awesome!
#
# the list of words ['rt', 'tell', 'your', 'kids', 'and', 'friends', 'about', 'the', 'new', 'website', 'we', 'developed', 'for', 'youth', 'totally', 'awesome!']
# all hashtags referenced ['melanoma']
# all twitter users mentioned ['acyr11', 'screenmemnc']
# all URLs []
# AFINN sentiment score 0
# ............................
# description: teacher, actress, director and speaker in DFW
# followers_count: 619
# friends_count: 1025
# favourites_count: 78
# location: Texas
# time_zone: Central Time (US & Canada)
# screen_name: polly_harrison
# name: Polly Harrison
# ====================================================================================
#
# the actual text of results[9]['text']
# retweet_count = 5
# favorite_count = 0
# ...................
# RT @acyr11: Tell your kids and friends about the new #melanoma website we developed for youth @screenmeMNC  - totally awesome!
#
# the list of words ['rt', 'tell', 'your', 'kids', 'and', 'friends', 'about', 'the', 'new', 'website', 'we', 'developed', 'for', 'youth', 'totally', 'awesome!']
# all hashtags referenced ['melanoma']
# all twitter users mentioned ['acyr11', 'screenmemnc']
# all URLs []
# AFINN sentiment score 0
# ............................
# description:
# followers_count: 62
# friends_count: 119
# favourites_count: 5
# location:
# time_zone: Eastern Time (US & Canada)
# screen_name: gwtodd
# name: George Todd
# ====================================================================================
#
# the actual text of results[10]['text']
# retweet_count = 5
# favorite_count = 0
# ...................
# RT @acyr11: Tell your kids and friends about the new #melanoma website we developed for youth @screenmeMNC  - totally awesome!
#
# the list of words ['rt', 'tell', 'your', 'kids', 'and', 'friends', 'about', 'the', 'new', 'website', 'we', 'developed', 'for', 'youth', 'totally', 'awesome!']
# all hashtags referenced ['melanoma']
# all twitter users mentioned ['acyr11', 'screenmemnc']
# all URLs []
# AFINN sentiment score 0
# ............................
# description: The Melanoma Network of Canada is a national patient-led organization dedicated to the prevention and elimination of melanoma.
# followers_count: 1409
# friends_count: 1031
# favourites_count: 43
# location: Canada
# time_zone: Quito
# screen_name: MelanomaNetwork
# name: Melanoma Network
# ====================================================================================
#
# the actual text of results[11]['text']
# retweet_count = 5
# favorite_count = 1
# ...................
# Tell your kids and friends about the new #melanoma website we developed for youth @screenmeMNC  - totally awesome!
#
# the list of words ['tell', 'your', 'kids', 'and', 'friends', 'about', 'the', 'new', 'website', 'we', 'developed', 'for', 'youth', 'totally', 'awesome!']
# all hashtags referenced ['melanoma']
# all twitter users mentioned ['screenmemnc']
# all URLs []
# AFINN sentiment score 0
# ............................
# description: Founder and Chair of the Board for the Melanoma Network of Canada.  Providing Education. Public Awareness, Patient Support Programs and Advocacy for Treatment.
# followers_count: 11
# friends_count: 12
# favourites_count: 0
# location: Oakville, Ontario
# time_zone: Eastern Time (US & Canada)
# screen_name: acyr11
# name: Annette Cyr
# ====================================================================================
#
# the actual text of results[12]['text']
# retweet_count = 13
# favorite_count = 0
# ...................
# RT @CureMelanoma: Today is National Nude Day! #GetNaked to look for any new/changing spots &amp; when you DO, apply sunscreen! http://t.co/Abpt…
# the list of words ['rt', 'today', 'is', 'national', 'nude', 'day!', 'to', 'look', 'for', 'any', 'new/changing', 'spots', 'when', 'you', 'do,', 'apply', 'sunscreen!']
# all hashtags referenced ['getnaked']
# all twitter users mentioned ['curemelanoma']
# all URLs ['http://t.co/abpt']
# AFINN sentiment score 0
# ............................
# description: you must love your crooked neighbor with all your crooked heart.
# followers_count: 2203
# friends_count: 78
# favourites_count: 1871
# location: Los Angeles, CA
# time_zone: Pacific Time (US & Canada)
# screen_name: AnaLucasey
# name: Ana Lucasey
# ====================================================================================
#
# the actual text of results[13]['text']
# retweet_count = 7
# favorite_count = 0
# ...................
# RT @Duke_Medicine: Your melanoma risk may be tied to your sun exposure as a youth. Know what to look for, and if you're at high risk. http:…
#
# the list of words ['rt', 'your', 'melanoma', 'risk', 'may', 'be', 'tied', 'to', 'your', 'sun', 'exposure', 'as', 'a', 'youth.', 'know', 'what', 'to', 'look', 'for,', 'and', 'if', "you're", 'at', 'high', 'risk.', 'http:\xe2\x80\xa6']
# all hashtags referenced []
# all twitter users mentioned ['duke_medicine']
# all URLs []
# AFINN sentiment score -2
# ............................
# description: Recurrent melanoma survivor, fighting Crohns disease; christian, kid at heart, youth advocate, who likes Apple products, pets and my waffle maker!
# followers_count: 43
# friends_count: 107
# favourites_count: 121
# location: Camlachie, Ontario, Canada
# time_zone: None
# screen_name: MLGoodacre
# name: ML Goodacre
# ====================================================================================
#
# the actual text of results[14]['text']
# retweet_count = 8
# favorite_count = 0
# ...................
# RT @SherryInk: I've been a #skincancer patient for 9 years #Melanoma #Blog #ItCanHappenToYou #Health #sunsafety http://t.co/qktkJjp1nc
#
# the list of words ['rt', "i've", 'been', 'a', 'patient', 'for', '9', 'years']
# all hashtags referenced ['skincancer', 'melanoma', 'blog', 'itcanhappentoyou', 'health', 'sunsafety']
# all twitter users mentioned ['sherryink']
# all URLs ['http://t.co/qktkjjp1nc']
# AFINN sentiment score 0
# ............................
# description: Head programmer Independent Technical Services
# followers_count: 1623
# friends_count: 1718
# favourites_count: 0
# location:
# time_zone: None
# screen_name: blanchette_jame
# name: James Blanchette
# ====================================================================================
#
# the actual text of results[15]['text']
# retweet_count = 8
# favorite_count = 0
# ...................
# RT @SherryInk: I've been a #skincancer patient for 9 years #Melanoma #Blog #ItCanHappenToYou #Health #sunsafety http://t.co/qktkJjp1nc
#
# the list of words ['rt', "i've", 'been', 'a', 'patient', 'for', '9', 'years']
# all hashtags referenced ['skincancer', 'melanoma', 'blog', 'itcanhappentoyou', 'health', 'sunsafety']
# all twitter users mentioned ['sherryink']
# all URLs ['http://t.co/qktkjjp1nc']
# AFINN sentiment score 0
# ............................
# description: My name is Janis Tafoya...I am an artist, to find some of my
# work please go to
# followers_count: 3713
# friends_count: 2018
# favourites_count: 17
# location:
# time_zone: None
# screen_name: janisfineart
# name: janis tafoya
# ====================================================================================
#
# the actual text of results[16]['text']
# retweet_count = 8
# favorite_count = 0
# ...................
# RT @SherryInk: I've been a #skincancer patient for 9 years #Melanoma #Blog #ItCanHappenToYou #Health #sunsafety http://t.co/qktkJjp1nc
#
# the list of words ['rt', "i've", 'been', 'a', 'patient', 'for', '9', 'years']
# all hashtags referenced ['skincancer', 'melanoma', 'blog', 'itcanhappentoyou', 'health', 'sunsafety']
# all twitter users mentioned ['sherryink']
# all URLs ['http://t.co/qktkjjp1nc']
# AFINN sentiment score 0
# ............................
# description: retraite, suis la bourse depuis plusieurs années,
# followers_count: 58
# friends_count: 24
# favourites_count: 4
# location: Lac St Jean, quebec, canada
# time_zone: Central Time (US & Canada)
# screen_name: visionvue
# name: tourtiere
# ====================================================================================
#
# the actual text of results[17]['text']
# retweet_count = 7
# favorite_count = 0
# ...................
# RT @UWCarbone: Cases of #Melanoma are still on the rise. July is #UVSafety Month, protect your skin: http://t.co/xzD2T9sGmI
#
# the list of words ['rt', 'cases', 'of', 'are', 'still', 'on', 'the', 'rise.', 'july', 'is', 'month,', 'protect', 'your', 'skin:']
# all hashtags referenced ['melanoma', 'uvsafety']
# all twitter users mentioned ['uwcarbone']
# all URLs ['http://t.co/xzd2t9sgmi']
# AFINN sentiment score 1
# ............................
# description: Nurturing woman, mother of two, entreprenurial spirited child of God
# followers_count: 255
# friends_count: 579
# favourites_count: 508
# location: Albany NY
# time_zone: Eastern Time (US & Canada)
# screen_name: WDeFazio
# name: Wendy DeFazio
# ====================================================================================
#
# the actual text of results[18]['text']
# retweet_count = 50
# favorite_count = 0
# ...................
# RT @WebMD: Signs you've overdone it, and how to prevent damage.
# http://t.co/WUerSHFVb1 http://t.co/uQO5ct6Bi5
#
# the list of words ['rt', 'signs', "you've", 'overdone', 'it,', 'and', 'how', 'to', 'prevent', 'damage.']
# all hashtags referenced []
# all twitter users mentioned ['webmd']
# all URLs ['http://t.co/wuershfvb1', 'http://t.co/uqo5ct6bi5']
# AFINN sentiment score -1
# ............................
# description: Healthy & Natural Skincare Products
# followers_count: 50
# friends_count: 611
# favourites_count: 5
# location: Dallas, Texas
# time_zone: None
# screen_name: NaturesSkinCare
# name: Deborah Renee
# ====================================================================================
#
# the actual text of results[19]['text']
# retweet_count = 6
# favorite_count = 0
# ...................
# RT @Roche: Roche provides update on Phase 3 study of investigational combo therapy in advanced melanoma: http://t.co/MDoEX2axow $ROG $RHHBY…
#
# the list of words ['rt', 'roche', 'provides', 'update', 'on', 'phase', '3', 'study', 'of', 'investigational', 'combo', 'therapy', 'in', 'advanced', 'melanoma:', '$rog', '$rhhby\xe2\x80\xa6']
# all hashtags referenced []
# all twitter users mentioned ['roche']
# all URLs ['http://t.co/mdoex2axow']
# AFINN sentiment score 1
# ............................
# description: Welcome to Patient Power Europe. We are devoted to providing cancer patients/survivors and families with the knowledge to get the best medicine and health.
# followers_count: 300
# friends_count: 1001
# favourites_count: 4
# location:
# time_zone: None
# screen_name: patientpowereu
# name: Patient Power Europe
# ====================================================================================
#
# the actual text of results[20]['text']
# retweet_count = 7
# favorite_count = 0
# ...................
# RT @Duke_Medicine: Your melanoma risk may be tied to your sun exposure as a youth. Know what to look for, and if you're at high risk. http:…
#
# the list of words ['rt', 'your', 'melanoma', 'risk', 'may', 'be', 'tied', 'to', 'your', 'sun', 'exposure', 'as', 'a', 'youth.', 'know', 'what', 'to', 'look', 'for,', 'and', 'if', "you're", 'at', 'high', 'risk.', 'http:\xe2\x80\xa6']
# all hashtags referenced []
# all twitter users mentioned ['duke_medicine']
# all URLs []
# AFINN sentiment score -2
# ............................
# description: Hard working father of 4.
# Tattoo bearer. Fishing junkie.
# Fighter of stage IIIC melanoma.
# Cancer sucks - love your skin.
# Villa fan.
# followers_count: 974
# friends_count: 2001
# favourites_count: 1910
# location: Ontario, Canada
# time_zone: None
# screen_name: limey1972
# name: Dave Cook
# ====================================================================================
#
# the actual text of results[21]['text']
# retweet_count = 7
# favorite_count = 0
# ...................
# RT @Duke_Medicine: Your melanoma risk may be tied to your sun exposure as a youth. Know what to look for, and if you're at high risk. http:…
#
# the list of words ['rt', 'your', 'melanoma', 'risk', 'may', 'be', 'tied', 'to', 'your', 'sun', 'exposure', 'as', 'a', 'youth.', 'know', 'what', 'to', 'look', 'for,', 'and', 'if', "you're", 'at', 'high', 'risk.', 'http:\xe2\x80\xa6']
# all hashtags referenced []
# all twitter users mentioned ['duke_medicine']
# all URLs []
# AFINN sentiment score -2
# ............................
# description: Profesora universitaria, dos hijos, dos perros, un jardín, muchos libros y amor a la vida
# followers_count: 1150
# friends_count: 1845
# favourites_count: 46
# location: En Valencia, Venezuela
# time_zone: Caracas
# screen_name: rolrose
# name: rosalba parra
# ====================================================================================
#
# the actual text of results[22]['text']
# retweet_count = 8
# favorite_count = 0
# ...................
# RT @SherryInk: I've been a #skincancer patient for 9 years #Melanoma #Blog #ItCanHappenToYou #Health #sunsafety http://t.co/qktkJjp1nc
#
# the list of words ['rt', "i've", 'been', 'a', 'patient', 'for', '9', 'years']
# all hashtags referenced ['skincancer', 'melanoma', 'blog', 'itcanhappentoyou', 'health', 'sunsafety']
# all twitter users mentioned ['sherryink']
# all URLs ['http://t.co/qktkjjp1nc']
# AFINN sentiment score 0
# ............................
# description: Official Twitter account for Verisante Technology, Inc.
# Verisante is committed to commercializing innovative systems for the early detection of cancer.
# followers_count: 288
# friends_count: 135
# favourites_count: 11
# location: Vancouver, BC
# time_zone: Pacific Time (US & Canada)
# screen_name: Verisante
# name: Verisante Technology
# ====================================================================================
#
# the actual text of results[23]['text']
# retweet_count = 8
# favorite_count = 0
# ...................
# RT @SherryInk: I've been a #skincancer patient for 9 years #Melanoma #Blog #ItCanHappenToYou #Health #sunsafety http://t.co/qktkJjp1nc
# the list of words ['rt', "i've", 'been', 'a', 'patient', 'for', '9', 'years']
# all hashtags referenced ['skincancer', 'melanoma', 'blog', 'itcanhappentoyou', 'health', 'sunsafety']
# all twitter users mentioned ['sherryink']
# all URLs ['http://t.co/qktkjjp1nc']
# AFINN sentiment score 0
# ............................
# description: Jesus is #1, happily married to Bill, love our family! http://t.co/8pPQSewWTI http://t.co/QJ63WAVlzH
# followers_count: 9875
# friends_count: 9732
# favourites_count: 37
# location: Barb's Burnt Tree Fine Art
# time_zone: Central Time (US & Canada)
# screen_name: BarbsBurntTree
# name: Barb
# ====================================================================================
#
# the actual text of results[24]['text']
# retweet_count = 7
# favorite_count = 0
# ...................
# RT @Duke_Medicine: Your melanoma risk may be tied to your sun exposure as a youth. Know what to look for, and if you're at high risk. http:…
#
# the list of words ['rt', 'your', 'melanoma', 'risk', 'may', 'be', 'tied', 'to', 'your', 'sun', 'exposure', 'as', 'a', 'youth.', 'know', 'what', 'to', 'look', 'for,', 'and', 'if', "you're", 'at', 'high', 'risk.', 'http:\xe2\x80\xa6']
# all hashtags referenced []
# all twitter users mentioned ['duke_medicine']
# all URLs []
# AFINN sentiment score -2
# ............................
# description:
# followers_count: 330
# friends_count: 515
# favourites_count: 107
# location: Raleigh, NC
# time_zone: Eastern Time (US & Canada)
# screen_name: doclobbyist
# name: Chip Baggett
# ====================================================================================
#
# the actual text of results[25]['text']
# retweet_count = 7
# favorite_count = 0
# ...................
# RT @Duke_Medicine: Your melanoma risk may be tied to your sun exposure as a youth. Know what to look for, and if you're at high risk. http:…
#
# the list of words ['rt', 'your', 'melanoma', 'risk', 'may', 'be', 'tied', 'to', 'your', 'sun', 'exposure', 'as', 'a', 'youth.', 'know', 'what', 'to', 'look', 'for,', 'and', 'if', "you're", 'at', 'high', 'risk.', 'http:\xe2\x80\xa6']
# all hashtags referenced []
# all twitter users mentioned ['duke_medicine']
# all URLs []
# AFINN sentiment score -2
# ............................
# description: Daphne's mom ~ Medstudent  ~
# Making my life a story worth telling...
# followers_count: 170
# friends_count: 320
# favourites_count: 798
# location: Bay Harbor Islands
# time_zone: Eastern Time (US & Canada)
# screen_name: aiarteaga
# name: Andrea Arteaga Icaza
# ====================================================================================
#
# the actual text of results[26]['text']
# retweet_count = 7
# favorite_count = 0
# ...................
# RT @Duke_Medicine: Your melanoma risk may be tied to your sun exposure as a youth. Know what to look for, and if you're at high risk. http:…
#
# the list of words ['rt', 'your', 'melanoma', 'risk', 'may', 'be', 'tied', 'to', 'your', 'sun', 'exposure', 'as', 'a', 'youth.', 'know', 'what', 'to', 'look', 'for,', 'and', 'if', "you're", 'at', 'high', 'risk.', 'http:\xe2\x80\xa6']
# all hashtags referenced []
# all twitter users mentioned ['duke_medicine']
# all URLs []
# AFINN sentiment score -2
# ............................
# description: Opinions expressed are my own.
# followers_count: 139
# friends_count: 361
# favourites_count: 61
# location: Kensington, MD
# time_zone: Eastern Time (US & Canada)
# screen_name: jloukissas
# name: Jennifer Loukissas
# ====================================================================================
#
# the actual text of results[27]['text']
# retweet_count = 7
# favorite_count = 2
# ...................
# Your melanoma risk may be tied to your sun exposure as a youth. Know what to look for, and if you're at high risk. http://t.co/Jde7O6avLE
#
# the list of words ['your', 'melanoma', 'risk', 'may', 'be', 'tied', 'to', 'your', 'sun', 'exposure', 'as', 'a', 'youth.', 'know', 'what', 'to', 'look', 'for,', 'and', 'if', "you're", 'at', 'high', 'risk.']
# all hashtags referenced []
# all twitter users mentioned []
# all URLs ['http://t.co/jde7o6avle']
# AFINN sentiment score -2
# ............................
# description: World-class academic and health care system
# followers_count: 25213
# friends_count: 318
# favourites_count: 0
# location: North Carolina
# time_zone: Central Time (US & Canada)
# screen_name: Duke_Medicine
# name: Duke Medicine
# ====================================================================================
#
# the actual text of results[28]['text']
# retweet_count = 6
# favorite_count = 0
# ...................
# RT @Roche: Roche provides update on Phase 3 study of investigational combo therapy in advanced melanoma: http://t.co/MDoEX2axow $ROG $RHHBY…
#
# the list of words ['rt', 'roche', 'provides', 'update', 'on', 'phase', '3', 'study', 'of', 'investigational', 'combo', 'therapy', 'in', 'advanced', 'melanoma:', '$rog', '$rhhby\xe2\x80\xa6']
# all hashtags referenced []
# all twitter users mentioned ['roche']
# all URLs ['http://t.co/mdoex2axow']
# AFINN sentiment score 1
# ............................
# description: I work in Cancer research, am a wife and mom to three sons.
# followers_count: 31
# friends_count: 111
# favourites_count: 29
# location:
# time_zone: None
# screen_name: julie9094
# name: Julie Catherman
# ====================================================================================
#
# the actual text of results[29]['text']
# retweet_count = 8
# favorite_count = 0
# ...................
# RT @SherryInk: I've been a #skincancer patient for 9 years #Melanoma #Blog #ItCanHappenToYou #Health #sunsafety http://t.co/qktkJjp1nc
#
# the list of words ['rt', "i've", 'been', 'a', 'patient', 'for', '9', 'years']
# all hashtags referenced ['skincancer', 'melanoma', 'blog', 'itcanhappentoyou', 'health', 'sunsafety']
# all twitter users mentioned ['sherryink']
# all URLs ['http://t.co/qktkjjp1nc']
# AFINN sentiment score 0
# ............................
# description: Published Photographer from Newcastle. I recently completed Ride4Red on the Blood Brothers Team for Bright Red (thanks to sponsors!!!). AKA Georden Photography
# followers_count: 1727
# friends_count: 1618
# favourites_count: 10030
# location: UK
# time_zone: London
# screen_name: 1Georden
# name: George Davidson
# ====================================================================================
#
# the actual text of results[30]['text']
# retweet_count = 8
# favorite_count = 0
# ...................
# RT @SherryInk: I've been a #skincancer patient for 9 years #Melanoma #Blog #ItCanHappenToYou #Health #sunsafety http://t.co/qktkJjp1nc
#
# the list of words ['rt', "i've", 'been', 'a', 'patient', 'for', '9', 'years']
# all hashtags referenced ['skincancer', 'melanoma', 'blog', 'itcanhappentoyou', 'health', 'sunsafety']
# all twitter users mentioned ['sherryink']
# all URLs ['http://t.co/qktkjjp1nc']
# AFINN sentiment score 0
# ............................
# description: I am also HelenLaura5, just a drinker writing a blog
# followers_count: 1686
# friends_count: 1971
# favourites_count: 1863
# location: Burlington
# time_zone: None
# screen_name: Skinnyandsingle
# name: Skinnyandsingle
# ====================================================================================
#
# the actual text of results[31]['text']
# retweet_count = 5
# favorite_count = 0
# ...................
# RT @myriadgenetics: Think eyes can't burn or get cancer? They do! Wear sunglasses that block both UVA &amp; UVB rays http://t.co/HNkhQpmoDP #me…
#
# the list of words ['rt', 'think', 'eyes', "can't", 'burn', 'or', 'get', 'cancer?', 'they', 'do!', 'wear', 'sunglasses', 'that', 'block', 'both', 'uva', 'uvb', 'rays']
# all hashtags referenced ['me']
# all twitter users mentioned ['myriadgenetics']
# all URLs ['http://t.co/hnkhqpmodp']
# AFINN sentiment score -1
# ............................
# description: Clinical Research & Publication Associate at Myriad Genetics
# followers_count: 51
# friends_count: 86
# favourites_count: 9
# location: Madrid
# time_zone: Athens
# screen_name: Aroa_S_C
# name: Aroa Sánchez
# ====================================================================================
#
# the actual text of results[32]['text']
# retweet_count = 7
# favorite_count = 0
# ...................
# RT @infosalus_com: Las cremas de protección solar no protegen totalmente del #melanoma http://t.co/a0fP8NaPVQ #Investigación http://t.co/46…
#
# the list of words ['rt', 'las', 'cremas', 'de', 'protecci\xc3\xb3n', 'solar', 'no', 'protegen', 'totalmente', 'del', '\xc3\xb3n']
# all hashtags referenced ['melanoma', 'investigaci']
# all twitter users mentioned ['infosalus_com']
# all URLs ['http://t.co/a0fp8napvq', 'http://t.co/46']
# AFINN sentiment score -1
# ............................
# description: Be kind, work hard, stay humble, smile often, stay loyal, keep onest, travel when is possible, never stop learning, be thankful always and love...
# followers_count: 61
# friends_count: 252
# favourites_count: 148
# location: Madrid
# time_zone: None
# screen_name: Mirella_Va_
# name: Mirella Va
# ====================================================================================
#
# the actual text of results[33]['text']
# retweet_count = 4
# favorite_count = 0
# ...................
# RT @jaq1979_jacqui: Another beautiful woman lost her battle with #melanoma :-( #skincancer is real and can be fatal folks :-( #avoidsunbeds…
#
# the list of words ['rt', 'another', 'beautiful', 'woman', 'lost', 'her', 'battle', 'with', ':-(', 'is', 'real', 'and', 'can', 'be', 'fatal', 'folks', ':-(']
# all hashtags referenced ['melanoma', 'skincancer', 'avoidsunbeds']
# all twitter users mentioned ['jaq1979_jacqui']
# all URLs []
# AFINN sentiment score -1
# ............................
# description: Stage 4 malignant melanoma patient campiagning to raise awareness of skin cancer and its causes
# https://t.co/b4ldqL4eq6
# followers_count: 1542
# friends_count: 1245
# favourites_count: 1472
# location: UK
# time_zone: London
# screen_name: capybara10
# name: Sunbed Ban UK
# ====================================================================================
#
# the actual text of results[34]['text']
# retweet_count = 4
# favorite_count = 0
# ...................
# RT @gh5moon: Startup Wins Funding For iPhone App To Scan Skin For Melanoma
#
# the list of words ['rt', 'startup', 'wins', 'funding', 'for', 'iphone', 'app', 'to', 'scan', 'skin', 'for', 'melanoma']
# all hashtags referenced []
# all twitter users mentioned ['gh5moon']
# all URLs []
# AFINN sentiment score 4
# ............................
# description: Christian,Conservative,Patriot,Artist, Vision Broker,sotomayor
# followers_count: 8
# friends_count: 7
# favourites_count: 0
# location: Albuquerque
# time_zone: Midway Island
# screen_name: w5qroguec
# name: Paxton Hoskins
# ====================================================================================
#
# the actual text of results[35]['text']
# retweet_count = 13
# favorite_count = 0
# ...................
# RT @CureMelanoma: Today is National Nude Day! #GetNaked to look for any new/changing spots &amp; when you DO, apply sunscreen! http://t.co/Abpt…
# the list of words ['rt', 'today', 'is', 'national', 'nude', 'day!', 'to', 'look', 'for', 'any', 'new/changing', 'spots', 'when', 'you', 'do,', 'apply', 'sunscreen!']
# all hashtags referenced ['getnaked']
# all twitter users mentioned ['curemelanoma']
# all URLs ['http://t.co/abpt']
# AFINN sentiment score 0
# ............................
# description: Wife, mommy, Rodan + Fields Dermatologists Consultant, coffee addict, book junkie, Melanoma Awareness Advocate. Blessed.
# followers_count: 461
# friends_count: 819
# favourites_count: 415
# location: OKC
# time_zone: None
# screen_name: desistout
# name: Desi Stout
# ====================================================================================
#
# the actual text of results[36]['text']
# retweet_count = 14
# favorite_count = 0
# ...................
# RT @Roche: Roche provides update on Phase 3 study of investigational combo therapy in advanced #melanoma - http://t.co/EyX8C7GcIE #pharma
#
# the list of words ['rt', 'roche', 'provides', 'update', 'on', 'phase', '3', 'study', 'of', 'investigational', 'combo', 'therapy', 'in', 'advanced']
# all hashtags referenced ['melanoma', 'pharma']
# all twitter users mentioned ['roche']
# all URLs ['http://t.co/eyx8c7gcie']
# AFINN sentiment score 1
# ............................
# description: MD, PhD. Medical Director at Roche Hellas. Married to Evi and have adopted the most adorable cat, Ramon. All views expressed are my own.
# followers_count: 97
# friends_count: 88
# favourites_count: 1
# location: Athens - Proud to be Greek.
# time_zone: Athens
# screen_name: CAntonopoulos
# name: Ch. Antonopoulos
# ====================================================================================
#
# the actual text of results[37]['text']
# retweet_count = 17
# favorite_count = 0
# ...................
# RT @SkinCancerOrg: #SkinCancer Fact: From ages 15-39, men are 55% more likely to die of #melanoma than women in the same age group.
#
# the list of words ['rt', 'fact:', 'from', 'ages', '15-39,', 'men', 'are', '55%', 'more', 'likely', 'to', 'die', 'of', 'than', 'women', 'in', 'the', 'same', 'age', 'group.']
# all hashtags referenced ['skincancer', 'melanoma']
# all twitter users mentioned ['skincancerorg']
# all URLs []
# AFINN sentiment score -3
# ............................
# description: Oakhurst is a community based, not for profit, primary health care center since 1980.
# followers_count: 39
# friends_count: 101
# favourites_count: 4
# location: Stone Mountain, Georgia
# time_zone: None
# screen_name: OakhurstMedical
# name: Oakhurst Medical Ctr
# ====================================================================================
#
# the actual text of results[38]['text']
# retweet_count = 17
# favorite_count = 0
# ...................
# RT @SkinCancerOrg: #SkinCancer Fact: From ages 15-39, men are 55% more likely to die of #melanoma than women in the same age group.
#
# the list of words ['rt', 'fact:', 'from', 'ages', '15-39,', 'men', 'are', '55%', 'more', 'likely', 'to', 'die', 'of', 'than', 'women', 'in', 'the', 'same', 'age', 'group.']
# all hashtags referenced ['skincancer', 'melanoma']
# all twitter users mentioned ['skincancerorg']
# all URLs []
# AFINN sentiment score -3
# ............................
# description: John E. Vine, MD specializes in Mohs micrographic surgery for the removal of skin cancer and cosmetic treatments.
# followers_count: 6
# friends_count: 35
# favourites_count: 0
# location: Plainsboro, NJ
# time_zone: Eastern Time (US & Canada)
# screen_name: johnvinemd
# name: John Vine, MD
# ====================================================================================
#
# the actual text of results[39]['text']
# retweet_count = 5
# favorite_count = 0
# ...................
# RT @liveactionfloyd: I hate when people say they're "working" on their tan. You're not working on anything, you're lying still getting mela…
#
# the list of words ['rt', 'i', 'hate', 'when', 'people', 'say', "they're", '"working"', 'on', 'their', 'tan.', "you're", 'not', 'working', 'on', 'anything,', "you're", 'lying', 'still', 'getting', 'mela\xe2\x80\xa6']
# all hashtags referenced []
# all twitter users mentioned ['liveactionfloyd']
# all URLs []
# AFINN sentiment score -3
# ............................
# description: Cycling advocate, runner, landlord, IT consultant. My thoughts are my own and may not reflect reality.
# followers_count: 119
# friends_count: 121
# favourites_count: 2859
# location: Dartmouth, NS
# time_zone: Atlantic Time (Canada)
# screen_name: IanMHFX
# name: I /\ I\I   /V\
# ====================================================================================
#
# the actual text of results[40]['text']
# retweet_count = 6
# favorite_count = 0
# ...................
# RT @Roche: Roche provides update on Phase 3 study of investigational combo therapy in advanced melanoma: http://t.co/MDoEX2axow $ROG $RHHBY…
#
# the list of words ['rt', 'roche', 'provides', 'update', 'on', 'phase', '3', 'study', 'of', 'investigational', 'combo', 'therapy', 'in', 'advanced', 'melanoma:', '$rog', '$rhhby\xe2\x80\xa6']
# all hashtags referenced []
# all twitter users mentioned ['roche']
# all URLs ['http://t.co/mdoex2axow']
# AFINN sentiment score 1
# ............................
# description: Innovation junkie, academically motivated, UX-focused, gym addict, glasses wearing, yogi.
# followers_count: 144
# friends_count: 222
# favourites_count: 190
# location: New York, NY
# time_zone: None
# screen_name: MattDGoff
# name: Matt Goff
# ====================================================================================
#
# the actual text of results[41]['text']
# retweet_count = 4
# favorite_count = 0
# ...................
# RT @PharmaNewsDaily: Pharma News: Roche's Phase III trial of melanoma combination therapy meets primary endpoint: Roche has release... http…
#
# the list of words ['rt', 'pharma', 'news:', "roche's", 'phase', 'iii', 'trial', 'of', 'melanoma', 'combination', 'therapy', 'meets', 'primary', 'endpoint:', 'roche', 'has', 'release...', 'http\xe2\x80\xa6']
# all hashtags referenced []
# all twitter users mentioned ['pharmanewsdaily']
# all URLs []
# AFINN sentiment score 0
# ............................
# description: 1972
# followers_count: 17
# friends_count: 26
# favourites_count: 81
# location: Cankaya - Ankara
# time_zone: None
# screen_name: CevreEczanesi
# name: Cevre Eczanesi
# ====================================================================================
#
# the actual text of results[42]['text']
# retweet_count = 4
# favorite_count = 0
# ...................
# MT @TanningisOut: @CityofVancouver No umbrellas used on Robson? #melanoma is rising, pls bring back shade! http://t.co/exDAlEvSWu
#
# the list of words ['mt', 'no', 'umbrellas', 'used', 'on', 'robson?', 'is', 'rising,', 'pls', 'bring', 'back', 'shade!']
# all hashtags referenced ['melanoma']
# all twitter users mentioned ['tanningisout', 'cityofvancouver']
# all URLs ['http://t.co/exdalevswu']
# AFINN sentiment score -1
# ............................
# description: Leading the fight against cancer through lifesaving research, prevention education, support programs & public policy advocacy.
# followers_count: 3821
# friends_count: 634
# favourites_count: 7
# location: British Columbia, Canada
# time_zone: Pacific Time (US & Canada)
# screen_name: cancersocietybc
# name: CDNCancerSocietyBCY
# ====================================================================================
#
# the actual text of results[43]['text']
# retweet_count = 6
# favorite_count = 0
# ...................
# RT @Roche: Roche provides update on Phase 3 study of investigational combo therapy in advanced melanoma: http://t.co/MDoEX2axow $ROG $RHHBY…
#
# the list of words ['rt', 'roche', 'provides', 'update', 'on', 'phase', '3', 'study', 'of', 'investigational', 'combo', 'therapy', 'in', 'advanced', 'melanoma:', '$rog', '$rhhby\xe2\x80\xa6']
# all hashtags referenced []
# all twitter users mentioned ['roche']
# all URLs ['http://t.co/mdoex2axow']
# AFINN sentiment score 1
# ............................
# description:
# followers_count: 51
# friends_count: 246
# favourites_count: 800
# location:
# time_zone: None
# screen_name: faralapilu
# name: Pilar Borraz
# ====================================================================================
#
# the actual text of results[44]['text']
# retweet_count = 13
# favorite_count = 0
# ...................
# RT @CureMelanoma: Today is National Nude Day! #GetNaked to look for any new/changing spots &amp; when you DO, apply sunscreen! http://t.co/Abpt…
#
# the list of words ['rt', 'today', 'is', 'national', 'nude', 'day!', 'to', 'look', 'for', 'any', 'new/changing', 'spots', 'when', 'you', 'do,', 'apply', 'sunscreen!']
# all hashtags referenced ['getnaked']
# all twitter users mentioned ['curemelanoma']
# all URLs ['http://t.co/abpt']
# AFINN sentiment score 0
# ............................
# description: Colossians 2:6
# followers_count: 160
# friends_count: 199
# favourites_count: 2167
# location:
# time_zone: Eastern Time (US & Canada)
# screen_name: megsimmons00
# name: Meg Simmons
# ====================================================================================
#
# the actual text of results[45]['text']
# retweet_count = 6
# favorite_count = 0
# ...................
# RT @Roche: Roche provides update on Phase 3 study of investigational combo therapy in advanced melanoma: http://t.co/MDoEX2axow $ROG $RHHBY…
#
# the list of words ['rt', 'roche', 'provides', 'update', 'on', 'phase', '3', 'study', 'of', 'investigational', 'combo', 'therapy', 'in', 'advanced', 'melanoma:', '$rog', '$rhhby\xe2\x80\xa6']
# all hashtags referenced []
# all twitter users mentioned ['roche']
# all URLs ['http://t.co/mdoex2axow']
# AFINN sentiment score 1
# ............................
# description: We put your lab at the center of everything we do.
# followers_count: 50
# friends_count: 488
# favourites_count: 5
# location: Cambridge, MA
# time_zone: Atlantic Time (Canada)
# screen_name: LabCentrix
# name: LabCentrix
# ====================================================================================
#
# the actual text of results[46]['text']
# retweet_count = 6
# favorite_count = 3
# ...................
# Roche provides update on Phase 3 study of investigational combo therapy in advanced melanoma: http://t.co/MDoEX2axow $ROG $RHHBY #melnm
#
# the list of words ['roche', 'provides', 'update', 'on', 'phase', '3', 'study', 'of', 'investigational', 'combo', 'therapy', 'in', 'advanced', 'melanoma:', '$rog', '$rhhby']
# all hashtags referenced ['melnm']
# all twitter users mentioned []
# all URLs ['http://t.co/mdoex2axow']
# AFINN sentiment score 1
# ............................
# description: Official Twitter handle for Roche with news & updates on doing now what patients need next.
# followers_count: 67785
# friends_count: 1483
# favourites_count: 391
# location: Basel, Switzerland
# time_zone: Bern
# screen_name: Roche
# name: Roche
# ====================================================================================

# %% [markdown]
# # Let's do a quick lexical analysis of these tweets

# %% [markdown]
# Step 1: Collect all the tweets in one string
#
# Note: the AFINN score will be for the entire string, which may or may not be helpful

# %%
tweets = ""
for i in range(num_tweets):
    tweets = tweets + " " + results[i]['text']

words, hashes, users, urls, AFINN_score = parse_tweet_text(tweets, AFINN=True)

print "AFINN sentiment score %d"%AFINN_score
# Out:
# AFINN sentiment score -18

# %% [markdown]
# Step 2: Remove the stop words
#
# Note: English stop words won't help in Espanish

# %%
from nltk.corpus import stopwords

stop = stopwords.words('english')
stop.append("it's")
stop.append('w/')

filtered_word_list = [word for word in words if word not in stop]
filtered_word_set  = set(filtered_word_list)

print "%d  total words"%len(filtered_word_list)
print "%d unique words"%len(filtered_word_set)
# Out:
# 495  total words
# 154 unique words

# %% [markdown]
# Step 3: Show the top 10 of each entity type
#
# Note: 'rt' means retweet and it's very common, but you may not consider it a word

# %%
from collections import Counter
from prettytable import PrettyTable

for label, data in (('Word', filtered_word_list), 
                    ('Users Mentioned', users), 
                    ('Hashtag', hashes),
                    ('URL', urls)):
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print pt
# Out:
# +----------+-------+
# | Word     | Count |
# +----------+-------+
# | rt       |    43 |
# | look     |    10 |
# | you're   |     9 |
# | melanoma |     9 |
# | years    |     8 |
# | therapy  |     8 |
# | patient  |     8 |
# | roche    |     8 |
# | i've     |     8 |
# | 9        |     8 |
# +----------+-------+
# +-----------------+-------+
# | Users Mentioned | Count |
# +-----------------+-------+
# | sherryink       |     8 |
# | duke_medicine   |     6 |
# | screenmemnc     |     6 |
# | roche           |     6 |
# | acyr11          |     5 |
# | cityofvancouver |     4 |
# | tanningisout    |     4 |
# | cancersocietybc |     3 |
# | curemelanoma    |     3 |
# | skincancerorg   |     2 |
# +-----------------+-------+
# +------------------+-------+
# | Hashtag          | Count |
# +------------------+-------+
# | melanoma         |    24 |
# | skincancer       |    11 |
# | itcanhappentoyou |     8 |
# | sunsafety        |     8 |
# | blog             |     8 |
# | health           |     8 |
# | getnaked         |     3 |
# | me               |     1 |
# | chooseskinhealth |     1 |
# | cancer           |     1 |
# +------------------+-------+
# +------------------------+-------+
# | URL                    | Count |
# +------------------------+-------+
# | http://t.co/qktkjjp1nc |     8 |
# | http://t.co/mdoex2axow |     6 |
# | http://t.co            |     3 |
# | http://t.co/abpt       |     3 |
# | http://t.co/xzd2t9sgmi |     1 |
# | http://t.co/eyx8c7gcie |     1 |
# | http://t.co/exdalevswu |     1 |
# | http://t.co/46         |     1 |
# | http://t.co/wuershfvb1 |     1 |
# | http://t.co/h8odxibrgj |     1 |
# +------------------------+-------+

# %% [markdown]
# Step 4: Lexical Diversity

# %%
from twitter_functions import lexical_diversity, average_words

print "Lexical Diversity"
print "words  %0.2f"%lexical_diversity(set(words), words) # word_list not filtered_word_list
print "hashes %0.2f"%lexical_diversity(set(hashes), hashes)
print "users  %0.2f"%lexical_diversity(set(users), users)
print "urls   %0.2f"%lexical_diversity(set(urls), urls)

print "\nAverage per tweet"
print "words           %0.2f"%average_words(words, num_tweets)
print "filtered words  %0.2f"%average_words(filtered_word_list, num_tweets)
print "hashes          %0.2f"%average_words(hashes, num_tweets)
print "users           %0.2f"%average_words(users, num_tweets)
print "urls            %0.2f"%average_words(urls, num_tweets)
# Out:
# Lexical Diversity
# words  0.26
# hashes 0.20
# users  0.38
# urls   0.48
#
# Average per tweet
# words           15.66
# filtered words  10.53
# hashes          1.68
# users           1.28
# urls            0.66

# %% [markdown]
# Step 5: Can't finish without this, right?
#
# Note 1: foreign-language codes often cause this to fail.
#
# Note 2: the lexical density determines the look of the result: a few words in a mass of many infrequent words makes for a more attractive picture.

# %%
from pytagcloud import create_tag_image, make_tags
import IPython.display

# 'rt' is very common and useless
filter_ex_rt = list(filtered_word_list)
while 'rt' in filter_ex_rt: filter_ex_rt.remove('rt')

for item in [filter_ex_rt]:
    c = Counter(item)

num_tags = min(75, len(c.most_common())-1)
tags     = make_tags(c.most_common()[:num_tags], maxsize=120)

create_tag_image(tags, 'wordcloud.png', size=(900,900), fontname='Lobster' )

IPython.display.display(IPython.display.Image(filename='wordcloud.png'))
