# %% [markdown]
# Online Twitter Basics
# ======================

# %% [markdown]
# ###This notebook goes step-by-step through logging onto Twitter, live, retrieving tweets by keyword and analyzing them.
#
# My thanks to Bill Howe of the University of Washington for his Coursera course *Introduction to Data Analysis* and Matthew A. Russell for his book *Mining the Social Web* for getting me started.
#
# Note 1: I run the IPython notebook in pylab=inline mode which makes it look like Matlab; this may mean that you will have to explicitly `import` some modules that I take for granted. Alternatively, you could configure yourself for pylab, which I obviously think is better.
#
# Note 2: Twitter very popular outside the United States. Many non-English languages have codesets that I don't handle properly leading to program failures. Keep calm and carry on: at worst, you'll have to restart the kernel.

# %% [markdown]
# ### Logon to Twitter

# %% [markdown]
# I have my Twitter credentials in a file `twitter_credential.py` ... you need to create your own as follows:
# ```python
# def twitter_credentials():
#     """
#     Generate your own Twitter credentials here:  https://apps.twitter.com/
#     """
#     api_key = " "
#     api_secret = " "
#
#     access_token_key = " "
#     access_token_secret = " "
#
#     return (api_key, api_secret, access_token_key, access_token_secret)
# ```

# %% [markdown]
# If you get a message similar to `<twitter.api.Twitter object at 0x000000000E79AAC8>`, you've succesfully signed on

# %%
from twitter_credentials import twitter_credentials # my credentials
token, token_secret, consumer_key, consumer_secret = twitter_credentials()

import oauth2 as oauth
import urllib2 as urllib
import twitter

auth = twitter.oauth.OAuth(consumer_key, consumer_secret, token, token_secret)

twitter_api = twitter.Twitter(auth=auth)
print twitter_api
# Out:
# <twitter.api.Twitter object at 0x0000000010898B38>

# %% [markdown]
# ###QT Console
# I like to run the qtconsole whenever I am using a notebook because it allows me to experiment on a command-line interface to the notebook's session, with all its current variables, etc.

# %%
# %qtconsole

# %% [markdown]
# ###`twitter_functions.py`
# I have a file `twitter_functions.py` that contains a number of utility functions. Find it on my GitHub repo: [grfiv/healthcare_twitter_analysis](https://github.com/grfiv/healthcare_twitter_analysis)
#
# You also need to have the `AFINN-111.txt` sentiment-word file installed.
#
# A note on `AFINN-111.txt`: the file has a tab delimiter separating words and phrases and their score. You can add your own n-grams as long as you retain the formatting. I strip out extra white space in phrases so you don't have to be exact in that regard. The sentiment score is simply the sum of the scores of any n-grams found in the text after urls, hashtags and users have been removed.

# %% [markdown]
# ### Make a simple query

# %% [markdown]
# Modify the word or phrase in `q = " ... "`. Only one term.
# Try changing `num_tweet_request`, too.

# %%
import json
from twitter_functions import twitter_search

num_tweet_request = 250

q = "Melanoma"
initial_results = twitter_search(twitter_api, q, max_results = num_tweet_request)

# %% [markdown]
# ### Filter by `retweet_count`

# %% [markdown]
# The idea is that the the best tweets are ones that have been retweeted. So we will keep only those tweets that have a `retweet_count` greater than some threshold.
#
# `favorite_count` is also supposed to have some bearing on importance but it's usually zero in the ones I've looked at.

# %%
retweet_threshold = 3

results = [tweet 
           for tweet in initial_results 
           if tweet['retweet_count'] > retweet_threshold]

num_tweets = len(results)
print "%d tweets received"%len(initial_results)
print "%d tweets after retweet filtering"%len(results)
# Out:
# 300 tweets received
# 45 tweets after retweet filtering

# %% [markdown]
# ### Display the raw json returned for one of the `num_tweets` results we asked for

# %%
# I commented this out because the list is very long
# However, to do any serious Twitter munging, you need to know all about this thing

#print json.dumps(results[1], indent=4)

# %% [markdown]
# ###Parse the 'text' field, which is the body of the tweet, for each of the `num_tweets` responses returned
# I use my utility function `parse_tweet_text` for the body of the tweet itself; it also returns the AFINN sentiment, for which you must have `AFINN-111.txt` installed. I parse the json directly for the other fields.
#
# A response of `[]` means nothing was returned for a particular 'entity'.

# %%
from twitter_functions import parse_tweet_text 

senders = []
for i in range(num_tweets):
    senders.append(results[i]['user']['name'])
    
    tweet_text = results[i]['text']
    words, hashes, users, urls, AFINN_score = parse_tweet_text(tweet_text, AFINN=True)

    print "the actual text of results[%d]['text']\nretweet_count  = %d\nfavorite_count = %d\n...................\n%s"%(i,results[i]['retweet_count'],results[i]['favorite_count'],tweet_text)
    print "\nthe list of words %s"%[word.encode('utf-8') for word in words]
    print "hashtags referenced %s"%[hash_.encode('utf-8') for hash_ in hashes]
    print "twitter users mentioned %s"%[user.encode('utf-8') for user in users]
    print "URLs %s"%[url.encode('utf-8') for url in urls]
    print "AFINN sentiment score %d"%AFINN_score
    print "............................"
    print "description: %s"%results[i]['user']['description']
    print "followers_count: %d"%results[i]['user']['followers_count']
    print "friends_count: %d"%results[i]['user']['friends_count']
    print "favourites_count: %d"%results[i]['user']['favourites_count']
    print "location: %s"%results[i]['user']['location']
    print "time_zone: %s"%results[i]['user']['time_zone']
    print "screen_name: %s"%results[i]['user']['screen_name']
    print "name: %s"%results[i]['user']['name']
    if results[i]['place'] is not None: print "place: %s"%results[i]['place']
    print "====================================================================================\n"
# Out:
# the actual text of results[0]['text']
# retweet_count  = 14
# favorite_count = 0
# ...................
# RT @theNCI: Melanoma, the most deadly form of skin cancer, can occur anywhere on the body: http://t.co/Mhx2k7LPfG http://t.co/Tz3n1tUcMH
#
# the list of words ['rt', 'melanoma,', 'the', 'most', 'deadly', 'form', 'of', 'skin', 'cancer,', 'can', 'occur', 'anywhere', 'on', 'the', 'body:']
# hashtags referenced []
# twitter users mentioned ['thenci']
# URLs ['http://t.co/mhx2k7lpfg', 'http://t.co/tz3n1tucmh']
# AFINN sentiment score 0
# ............................
# description: Professor of Inst. of Materials Sci. and Nanotechnology and National Nanotechnology Research Center (UNAM), Bilkent University, Ankara, TURKEY (personal views)
# followers_count: 207
# friends_count: 436
# favourites_count: 13
# location: Ankara / Türkiye
# time_zone: Istanbul
# screen_name: mustafaoguler
# name: Mustafa O. Guler
# ====================================================================================
#
# the actual text of results[1]['text']
# retweet_count  = 14
# favorite_count = 0
# ...................
# RT @theNCI: Melanoma, the most deadly form of skin cancer, can occur anywhere on the body: http://t.co/Mhx2k7LPfG http://t.co/Tz3n1tUcMH
#
# the list of words ['rt', 'melanoma,', 'the', 'most', 'deadly', 'form', 'of', 'skin', 'cancer,', 'can', 'occur', 'anywhere', 'on', 'the', 'body:']
# hashtags referenced []
# twitter users mentioned ['thenci']
# URLs ['http://t.co/mhx2k7lpfg', 'http://t.co/tz3n1tucmh']
# AFINN sentiment score 0
# ............................
# description: St. Luke’s Cornwall Hospital is committed to providing for the diverse health care needs of the mid-Hudson Valley.
# followers_count: 196
# friends_count: 194
# favourites_count: 48
# location: Newburgh, NY
# time_zone: Atlantic Time (Canada)
# screen_name: SLCHospital
# name: SLCH
# ====================================================================================
#
# the actual text of results[2]['text']
# retweet_count  = 14
# favorite_count = 0
# ...................
# RT @theNCI: Melanoma, the most deadly form of skin cancer, can occur anywhere on the body: http://t.co/Mhx2k7LPfG http://t.co/Tz3n1tUcMH
#
# the list of words ['rt', 'melanoma,', 'the', 'most', 'deadly', 'form', 'of', 'skin', 'cancer,', 'can', 'occur', 'anywhere', 'on', 'the', 'body:']
# hashtags referenced []
# twitter users mentioned ['thenci']
# URLs ['http://t.co/mhx2k7lpfg', 'http://t.co/tz3n1tucmh']
# AFINN sentiment score 0
# ............................
# description: I have a dream: that one day there will be a greater Kurdistan. A free Kurdistan. #TwitterKurds
# followers_count: 1376
# friends_count: 147
# favourites_count: 3717
# location: UK
# time_zone: Amsterdam
# screen_name: NigeenAkram
# name: Nigeen
# ====================================================================================
#
# the actual text of results[3]['text']
# retweet_count  = 14
# favorite_count = 0
# ...................
# RT @theNCI: Melanoma, the most deadly form of skin cancer, can occur anywhere on the body: http://t.co/Mhx2k7LPfG http://t.co/Tz3n1tUcMH
#
# the list of words ['rt', 'melanoma,', 'the', 'most', 'deadly', 'form', 'of', 'skin', 'cancer,', 'can', 'occur', 'anywhere', 'on', 'the', 'body:']
# hashtags referenced []
# twitter users mentioned ['thenci']
# URLs ['http://t.co/mhx2k7lpfg', 'http://t.co/tz3n1tucmh']
# AFINN sentiment score 0
# ............................
# description: Latest breaking medical news and information tweeted and retweeted 24/7.
# followers_count: 798
# friends_count: 599
# favourites_count: 0
# location: L.A.
# time_zone: None
# screen_name: 1MEDICAL2NEWS
# name: Dr. Richard Billard
# ====================================================================================
#
# the actual text of results[4]['text']
# retweet_count  = 14
# favorite_count = 0
# ...................
# RT @theNCI: Melanoma, the most deadly form of skin cancer, can occur anywhere on the body: http://t.co/Mhx2k7LPfG http://t.co/Tz3n1tUcMH
#
# the list of words ['rt', 'melanoma,', 'the', 'most', 'deadly', 'form', 'of', 'skin', 'cancer,', 'can', 'occur', 'anywhere', 'on', 'the', 'body:']
# hashtags referenced []
# twitter users mentioned ['thenci']
# URLs ['http://t.co/mhx2k7lpfg', 'http://t.co/tz3n1tucmh']
# AFINN sentiment score 0
# ............................
# description: Virginia Bioinformatics Institute at Virginia Tech invents the future through bioinformatics, high-performance computing, and network simulation science.
# followers_count: 369
# friends_count: 436
# favourites_count: 334
# location: Blacksburg, VA
# time_zone: Eastern Time (US & Canada)
# screen_name: vbi_vt
# name: VaBioinformaticsVT
# ====================================================================================
#
# the actual text of results[5]['text']
# retweet_count  = 14
# favorite_count = 0
# ...................
# RT @theNCI: Melanoma, the most deadly form of skin cancer, can occur anywhere on the body: http://t.co/Mhx2k7LPfG http://t.co/Tz3n1tUcMH
#
# the list of words ['rt', 'melanoma,', 'the', 'most', 'deadly', 'form', 'of', 'skin', 'cancer,', 'can', 'occur', 'anywhere', 'on', 'the', 'body:']
# hashtags referenced []
# twitter users mentioned ['thenci']
# URLs ['http://t.co/mhx2k7lpfg', 'http://t.co/tz3n1tucmh']
# AFINN sentiment score 0
# ............................
# description: Founder/CEO SURIVIVEiT™
# followers_count: 41
# friends_count: 174
# favourites_count: 14
# location:
# time_zone: Central Time (US & Canada)
# screen_name: matt_surviveIT
# name: Matt Ellefson
# ====================================================================================
#
# the actual text of results[6]['text']
# retweet_count  = 14
# favorite_count = 0
# ...................
# RT @theNCI: Melanoma, the most deadly form of skin cancer, can occur anywhere on the body: http://t.co/Mhx2k7LPfG http://t.co/Tz3n1tUcMH
#
# the list of words ['rt', 'melanoma,', 'the', 'most', 'deadly', 'form', 'of', 'skin', 'cancer,', 'can', 'occur', 'anywhere', 'on', 'the', 'body:']
# hashtags referenced []
# twitter users mentioned ['thenci']
# URLs ['http://t.co/mhx2k7lpfg', 'http://t.co/tz3n1tucmh']
# AFINN sentiment score 0
# ............................
# description:
# followers_count: 119
# friends_count: 843
# favourites_count: 32
# location: Milano
# time_zone: None
# screen_name: josea69
# name: Jose Franco
# ====================================================================================
#
# the actual text of results[7]['text']
# retweet_count  = 14
# favorite_count = 0
# ...................
# RT @theNCI: Melanoma, the most deadly form of skin cancer, can occur anywhere on the body: http://t.co/Mhx2k7LPfG http://t.co/Tz3n1tUcMH
#
# the list of words ['rt', 'melanoma,', 'the', 'most', 'deadly', 'form', 'of', 'skin', 'cancer,', 'can', 'occur', 'anywhere', 'on', 'the', 'body:']
# hashtags referenced []
# twitter users mentioned ['thenci']
# URLs ['http://t.co/mhx2k7lpfg', 'http://t.co/tz3n1tucmh']
# AFINN sentiment score 0
# ............................
# description: Leading the way in health care in central Illinois, http://t.co/RQeOCpxPsq
# followers_count: 773
# friends_count: 451
# favourites_count: 292
# location: Springfield, Illinois
# time_zone: Mountain Time (US & Canada)
# screen_name: SpfldClinic
# name: Springfield Clinic
# ====================================================================================
#
# the actual text of results[8]['text']
# retweet_count  = 14
# favorite_count = 0
# ...................
# RT @theNCI: Melanoma, the most deadly form of skin cancer, can occur anywhere on the body: http://t.co/Mhx2k7LPfG http://t.co/Tz3n1tUcMH
#
# the list of words ['rt', 'melanoma,', 'the', 'most', 'deadly', 'form', 'of', 'skin', 'cancer,', 'can', 'occur', 'anywhere', 'on', 'the', 'body:']
# hashtags referenced []
# twitter users mentioned ['thenci']
# URLs ['http://t.co/mhx2k7lpfg', 'http://t.co/tz3n1tucmh']
# AFINN sentiment score 0
# ............................
# description: SOY UNA TICA ENAMORADA DE MI DIOS, MI FAMILIA, COSTA RICA MI PAÍS. .ME ENCANTA LA FOTOGRAFÍA, EL DEPORTE, LA POLÍTICA, LA MÚSICA  ..LA FIESTA..LA CERVEZA
# followers_count: 1356
# friends_count: 1998
# favourites_count: 6652
# location: Moravia, San Jose,Costa Rica
# time_zone: Central America
# screen_name: Marlenetica
# name: Marlene Hernandez
# ====================================================================================
#
# the actual text of results[9]['text']
# retweet_count  = 14
# favorite_count = 0
# ...................
# RT @theNCI: Melanoma, the most deadly form of skin cancer, can occur anywhere on the body: http://t.co/Mhx2k7LPfG http://t.co/Tz3n1tUcMH
#
# the list of words ['rt', 'melanoma,', 'the', 'most', 'deadly', 'form', 'of', 'skin', 'cancer,', 'can', 'occur', 'anywhere', 'on', 'the', 'body:']
# hashtags referenced []
# twitter users mentioned ['thenci']
# URLs ['http://t.co/mhx2k7lpfg', 'http://t.co/tz3n1tucmh']
# AFINN sentiment score 0
# ............................
# description: Cirujano Oncólogo/ Mastologo/ Presidente Sociedad Venezolana de Mastología/ Adjunto Servicio de Patología Mamaria Hospital Oncológico Padre Machado. Caracas
# followers_count: 745
# friends_count: 1624
# favourites_count: 440
# location: Caracas
# time_zone: Caracas
# screen_name: jcragostini
# name: Juan C. Rodríguez A.
# ====================================================================================
#
# the actual text of results[10]['text']
# retweet_count  = 14
# favorite_count = 4
# ...................
# Melanoma, the most deadly form of skin cancer, can occur anywhere on the body: http://t.co/Mhx2k7LPfG http://t.co/Tz3n1tUcMH
#
# the list of words ['melanoma,', 'the', 'most', 'deadly', 'form', 'of', 'skin', 'cancer,', 'can', 'occur', 'anywhere', 'on', 'the', 'body:']
# hashtags referenced []
# twitter users mentioned []
# URLs ['http://t.co/mhx2k7lpfg', 'http://t.co/tz3n1tucmh']
# AFINN sentiment score 0
# ............................
# description: Updates from the U.S. government’s lead agency for cancer research. Follows and retweets are not endorsements. Privacy: http://t.co/gFvBNAjIKT
# followers_count: 58532
# friends_count: 821
# favourites_count: 1261
# location: Bethesda, MD
# time_zone: Eastern Time (US & Canada)
# screen_name: theNCI
# name: National Cancer Inst
# ====================================================================================
#
# the actual text of results[11]['text']
# retweet_count  = 11
# favorite_count = 0
# ...................
# RT @Merck: Melanoma is the most dangerous form of skin cancer. Learn more and get tips to help protect yourself: http://t.co/1QmUg9TGwl #Me…
#
# the list of words ['rt', 'melanoma', 'is', 'the', 'most', 'dangerous', 'form', 'of', 'skin', 'cancer.', 'learn', 'more', 'and', 'get', 'tips', 'to', 'help', 'protect', 'yourself:']
# hashtags referenced ['me']
# twitter users mentioned ['merck']
# URLs ['http://t.co/1qmug9tgwl']
# AFINN sentiment score 3
# ............................
# description: Laboratorio especializado en la prestación de servicios de Detección Molecular de enfermedades infecciosas en humanos y pruebas de ADN en animales.
# followers_count: 90
# friends_count: 134
# favourites_count: 0
# location: Bogotá D.C. Colombia
# time_zone: Eastern Time (US & Canada)
# screen_name: BiotecgenSA
# name: Biotecgen SA
# ====================================================================================
#
# the actual text of results[12]['text']
# retweet_count  = 13
# favorite_count = 0
# ...................
# RT @embeedub: Reminder that @lululemon is full of shit, from a Stage 4 melanoma survivor: http://t.co/GZbVe91xDb
#
# the list of words ['rt', 'reminder', 'that', 'is', 'full', 'of', 'shit,', 'from', 'a', 'stage', '4', 'melanoma', 'survivor:']
# hashtags referenced []
# twitter users mentioned ['embeedub', 'lululemon']
# URLs ['http://t.co/gzbve91xdb']
# AFINN sentiment score 0
# ............................
# description: ESL instructor, mother, runner, cook, and very crabby woman.
# followers_count: 35
# friends_count: 114
# favourites_count: 222
# location: Spearville, KS
# time_zone: None
# screen_name: reallymarti
# name: marti
# ====================================================================================
#
# the actual text of results[13]['text']
# retweet_count  = 4
# favorite_count = 0
# ...................
# RT @MelanomaReAlli: Are you going to @IdolsLiveTour? For every ticket purchased @AmericanIdol donates $1 to MRA to help cure #melanoma. htt…
# the list of words ['rt', 'are', 'you', 'going', 'to', 'for', 'every', 'ticket', 'purchased', 'donates', '$1', 'to', 'mra', 'to', 'help', 'cure', 'htt\xe2\x80\xa6']
# hashtags referenced ['melanoma']
# twitter users mentioned ['melanomarealli', 'idolslivetour', 'americanidol']
# URLs []
# AFINN sentiment score 2
# ............................
# description:
# followers_count: 31
# friends_count: 23
# favourites_count: 990
# location:
# time_zone: None
# screen_name: klemmervinny
# name: Vinny Klemmer
# ====================================================================================
#
# the actual text of results[14]['text']
# retweet_count  = 8
# favorite_count = 0
# ...................
# RT @BostonTweet: The Boston 5K Summer Series to @RaceCancer and fight melanoma is Thursday with post-race beer from @LongTrailBeer. http://…
#
# the list of words ['rt', 'the', 'boston', '5k', 'summer', 'series', 'to', 'and', 'fight', 'melanoma', 'is', 'thursday', 'with', 'post-race', 'beer', 'from', 'http://\xe2\x80\xa6']
# hashtags referenced []
# twitter users mentioned ['bostontweet', 'racecancer', 'longtrailbeer']
# URLs []
# AFINN sentiment score -1
# ............................
# description: Irish Temper, Italian Attitude
# followers_count: 623
# friends_count: 74
# favourites_count: 38
# location: Florida✈Colorado✈New England
# time_zone: Mountain Time (US & Canada)
# screen_name: trainmilehigh
# name: Jennifer Kenny
# ====================================================================================
#
# the actual text of results[15]['text']
# retweet_count  = 8
# favorite_count = 0
# ...................
# RT @BostonTweet: The Boston 5K Summer Series to @RaceCancer and fight melanoma is Thursday with post-race beer from @LongTrailBeer. http://…
#
# the list of words ['rt', 'the', 'boston', '5k', 'summer', 'series', 'to', 'and', 'fight', 'melanoma', 'is', 'thursday', 'with', 'post-race', 'beer', 'from', 'http://\xe2\x80\xa6']
# hashtags referenced []
# twitter users mentioned ['bostontweet', 'racecancer', 'longtrailbeer']
# URLs []
# AFINN sentiment score -1
# ............................
# description: My peace of mind is not disturbed today by things beyond my control. Instagram: melissasheehan
# followers_count: 244
# friends_count: 184
# favourites_count: 9090
# location: Boston, MA
# time_zone: Quito
# screen_name: melissacsheehan
# name: Melissa⚓️Sheehan
# ====================================================================================
#
# the actual text of results[16]['text']
# retweet_count  = 8
# favorite_count = 0
# ...................
# RT @BostonTweet: The Boston 5K Summer Series to @RaceCancer and fight melanoma is Thursday with post-race beer from @LongTrailBeer. http://…
#
# the list of words ['rt', 'the', 'boston', '5k', 'summer', 'series', 'to', 'and', 'fight', 'melanoma', 'is', 'thursday', 'with', 'post-race', 'beer', 'from', 'http://\xe2\x80\xa6']
# hashtags referenced []
# twitter users mentioned ['bostontweet', 'racecancer', 'longtrailbeer']
# URLs []
# AFINN sentiment score -1
# ............................
# description: Making events more friendly.
# followers_count: 2267
# friends_count: 1775
# favourites_count: 76
# location: Boston, MA - USA
# time_zone: Eastern Time (US & Canada)
# screen_name: racemenu
# name: RaceMenu
# ====================================================================================
#
# the actual text of results[17]['text']
# retweet_count  = 6
# favorite_count = 0
# ...................
# RT @doubledoc630: New day in #Melanoma treatment through immunotherapy. Find #Clinicaltrials at http://t.co/Brp7mc7XeS  http://t.co/GUQUfWR…
#
# the list of words ['rt', 'new', 'day', 'in', 'treatment', 'through', 'immunotherapy.', 'find', 'at']
# hashtags referenced ['melanoma', 'clinicaltrials']
# twitter users mentioned ['doubledoc630']
# URLs ['http://t.co/brp7mc7xes', 'http://t.co/guqufwr']
# AFINN sentiment score 0
# ............................
# description: Managing Director, Future Factory
# Chairman of the Board, GuideStar Clinical Trials Management
# followers_count: 110
# friends_count: 21
# favourites_count: 3
# location: New York City
# time_zone: Eastern Time (US & Canada)
# screen_name: EMReggie
# name: Ed Michael Reggie
# ====================================================================================
#
# the actual text of results[18]['text']
# retweet_count  = 8
# favorite_count = 0
# ...................
# RT @BostonTweet: The Boston 5K Summer Series to @RaceCancer and fight melanoma is Thursday with post-race beer from @LongTrailBeer. http://…
#
# the list of words ['rt', 'the', 'boston', '5k', 'summer', 'series', 'to', 'and', 'fight', 'melanoma', 'is', 'thursday', 'with', 'post-race', 'beer', 'from', 'http://\xe2\x80\xa6']
# hashtags referenced []
# twitter users mentioned ['bostontweet', 'racecancer', 'longtrailbeer']
# URLs []
# AFINN sentiment score -1
# ............................
# description: Former Miss Mass. #MBA. #Marketing Professional. 6x #MARATHONER. @BabsonGraduate & @BrandeisU Alum. Co-founder of @runHAPPYraces. Loves #travel & #philanthropy
# followers_count: 1912
# friends_count: 986
# favourites_count: 1697
# location: Massachusetts
# time_zone: Eastern Time (US & Canada)
# screen_name: MissMass_2009
# name: Amanda Kelly Silbs
# ====================================================================================
#
# the actual text of results[19]['text']
# retweet_count  = 11
# favorite_count = 0
# ...................
# RT @Merck: Melanoma is the most dangerous form of skin cancer. Learn more and get tips to help protect yourself: http://t.co/1QmUg9TGwl #Me…
#
# the list of words ['rt', 'melanoma', 'is', 'the', 'most', 'dangerous', 'form', 'of', 'skin', 'cancer.', 'learn', 'more', 'and', 'get', 'tips', 'to', 'help', 'protect', 'yourself:']
# hashtags referenced ['me']
# twitter users mentioned ['merck']
# URLs ['http://t.co/1qmug9tgwl']
# AFINN sentiment score 3
# ............................
# description:
# followers_count: 42
# friends_count: 86
# favourites_count: 56
# location:
# time_zone: Athens
# screen_name: margaritabergia
# name: margarita bergia
# ====================================================================================
#
# the actual text of results[20]['text']
# retweet_count  = 8
# favorite_count = 0
# ...................
# RT @BostonTweet: The Boston 5K Summer Series to @RaceCancer and fight melanoma is Thursday with post-race beer from @LongTrailBeer. http://…
#
# the list of words ['rt', 'the', 'boston', '5k', 'summer', 'series', 'to', 'and', 'fight', 'melanoma', 'is', 'thursday', 'with', 'post-race', 'beer', 'from', 'http://\xe2\x80\xa6']
# hashtags referenced []
# twitter users mentioned ['bostontweet', 'racecancer', 'longtrailbeer']
# URLs []
# AFINN sentiment score -1
# ............................
# description: Rick Aronofsky is the host of the award winning TV talk show called Red Sox Weekly. Rick is also the director/producer of Sports forum.
# followers_count: 888
# friends_count: 2000
# favourites_count: 171
# location: Wilmington MA
# time_zone: Eastern Time (US & Canada)
# screen_name: wctvhost
# name: Red Sox Weekly
# ====================================================================================
#
# the actual text of results[21]['text']
# retweet_count  = 8
# favorite_count = 0
# ...................
# RT @BostonTweet: The Boston 5K Summer Series to @RaceCancer and fight melanoma is Thursday with post-race beer from @LongTrailBeer. http://…
#
# the list of words ['rt', 'the', 'boston', '5k', 'summer', 'series', 'to', 'and', 'fight', 'melanoma', 'is', 'thursday', 'with', 'post-race', 'beer', 'from', 'http://\xe2\x80\xa6']
# hashtags referenced []
# twitter users mentioned ['bostontweet', 'racecancer', 'longtrailbeer']
# URLs []
# AFINN sentiment score -1
# ............................
# description: Bow tie wearing President of the Octagonal Homeowners' Association, husband, runner, & aspiring chainsaw artist.
# followers_count: 549
# friends_count: 422
# favourites_count: 1210
# location:
# time_zone: Eastern Time (US & Canada)
# screen_name: JoshWarrun
# name: Joshua Warren
# ====================================================================================
#
# the actual text of results[22]['text']
# retweet_count  = 8
# favorite_count = 7
# ...................
# The Boston 5K Summer Series to @RaceCancer and fight melanoma is Thursday with post-race beer from @LongTrailBeer. http://t.co/kfRPyuJV6B
#
# the list of words ['the', 'boston', '5k', 'summer', 'series', 'to', 'and', 'fight', 'melanoma', 'is', 'thursday', 'with', 'post-race', 'beer', 'from']
# hashtags referenced []
# twitter users mentioned ['racecancer', 'longtrailbeer']
# URLs ['http://t.co/kfrpyujv6b']
# AFINN sentiment score -1
# ............................
# description: BostonTweet is all about loving life in Boston and things to do of value in the city. #DownloadBoston
# followers_count: 117101
# friends_count: 4930
# favourites_count: 358
# location: Boston, MA
# time_zone: Eastern Time (US & Canada)
# screen_name: BostonTweet
# name: BostonTweet
# ====================================================================================
#
# the actual text of results[23]['text']
# retweet_count  = 4
# favorite_count = 0
# ...................
# RT @MelanomaReAlli: Are you going to @IdolsLiveTour? For every ticket purchased @AmericanIdol donates $1 to MRA to help cure #melanoma. htt…
#
# the list of words ['rt', 'are', 'you', 'going', 'to', 'for', 'every', 'ticket', 'purchased', 'donates', '$1', 'to', 'mra', 'to', 'help', 'cure', 'htt\xe2\x80\xa6']
# hashtags referenced ['melanoma']
# twitter users mentioned ['melanomarealli', 'idolslivetour', 'americanidol']
# URLs []
# AFINN sentiment score 2
# ............................
# description:
# followers_count: 58
# friends_count: 46
# favourites_count: 1417
# location:
# time_zone: None
# screen_name: somer_hawke
# name: Somer Klemmer
# ====================================================================================
#
# the actual text of results[24]['text']
# retweet_count  = 11
# favorite_count = 0
# ...................
# RT @Merck: Melanoma is the most dangerous form of skin cancer. Learn more and get tips to help protect yourself: http://t.co/1QmUg9TGwl #Me…
#
# the list of words ['rt', 'melanoma', 'is', 'the', 'most', 'dangerous', 'form', 'of', 'skin', 'cancer.', 'learn', 'more', 'and', 'get', 'tips', 'to', 'help', 'protect', 'yourself:']
# hashtags referenced ['me']
# twitter users mentioned ['merck']
# URLs ['http://t.co/1qmug9tgwl']
# AFINN sentiment score 3
# ............................
# description: Quorum Review IRB is an AAHRPP accredited ethics review board.  Our mission is to protect patient safety while providing best-in-class customer service.
# followers_count: 706
# friends_count: 1932
# favourites_count: 68
# location: Seattle, WA
# time_zone: Pacific Time (US & Canada)
# screen_name: quorumreview
# name: Quorum Review - IRB
# ====================================================================================
#
# the actual text of results[25]['text']
# retweet_count  = 13
# favorite_count = 0
# ...................
# RT @embeedub: Reminder that @lululemon is full of shit, from a Stage 4 melanoma survivor: http://t.co/GZbVe91xDb
# the list of words ['rt', 'reminder', 'that', 'is', 'full', 'of', 'shit,', 'from', 'a', 'stage', '4', 'melanoma', 'survivor:']
# hashtags referenced []
# twitter users mentioned ['embeedub', 'lululemon']
# URLs ['http://t.co/gzbve91xdb']
# AFINN sentiment score 0
# ............................
# description: Taking the unnecessary guilt and anxiety out of motherhood. Type Z Moms is a support and resource website for great moms who aren't perfect.
# followers_count: 24
# friends_count: 40
# favourites_count: 71
# location:
# time_zone: None
# screen_name: TypeZMoms
# name: Type Z Moms
# ====================================================================================
#
# the actual text of results[26]['text']
# retweet_count  = 6
# favorite_count = 0
# ...................
# RT @CureMelanoma: .@lululemon admits anti-sunscreen language is not research-based http://t.co/bB1v3Ljtkk #prevention #melanoma #skincancer
#
# the list of words ['rt', 'admits', 'anti-sunscreen', 'language', 'is', 'not', 'research-based']
# hashtags referenced ['prevention', 'melanoma', 'skincancer']
# twitter users mentioned ['curemelanoma', 'lululemon']
# URLs ['http://t.co/bb1v3ljtkk']
# AFINN sentiment score -1
# ............................
# description: We are a premier dermatology practice located in Toronto, Ontario that is dedicated to offering the best comprehensive and personalized care.
# followers_count: 109
# friends_count: 116
# favourites_count: 1
# location: Toronto, ON, Canada
# time_zone: Eastern Time (US & Canada)
# screen_name: DermOnBloor
# name: Dermonbloor
# ====================================================================================
#
# the actual text of results[27]['text']
# retweet_count  = 11
# favorite_count = 0
# ...................
# RT @Merck: Melanoma is the most dangerous form of skin cancer. Learn more and get tips to help protect yourself: http://t.co/1QmUg9TGwl #Me…
#
# the list of words ['rt', 'melanoma', 'is', 'the', 'most', 'dangerous', 'form', 'of', 'skin', 'cancer.', 'learn', 'more', 'and', 'get', 'tips', 'to', 'help', 'protect', 'yourself:']
# hashtags referenced ['me']
# twitter users mentioned ['merck']
# URLs ['http://t.co/1qmug9tgwl']
# AFINN sentiment score 3
# ............................
# description: Financial Advisor with Blakely Financial, Inc.
# followers_count: 22
# friends_count: 158
# favourites_count: 4
# location: High Point, NC
# time_zone: Eastern Time (US & Canada)
# screen_name: CFNwillarmfield
# name: Will Armfield
# ====================================================================================
#
# the actual text of results[28]['text']
# retweet_count  = 11
# favorite_count = 0
# ...................
# RT @Merck: Melanoma is the most dangerous form of skin cancer. Learn more and get tips to help protect yourself: http://t.co/1QmUg9TGwl #Me…
#
# the list of words ['rt', 'melanoma', 'is', 'the', 'most', 'dangerous', 'form', 'of', 'skin', 'cancer.', 'learn', 'more', 'and', 'get', 'tips', 'to', 'help', 'protect', 'yourself:']
# hashtags referenced ['me']
# twitter users mentioned ['merck']
# URLs ['http://t.co/1qmug9tgwl']
# AFINN sentiment score 3
# ............................
# description: Elma Research is a market research company specializing in the medical-pharmaceutical sector and in the area of general health.
# followers_count: 331
# friends_count: 354
# favourites_count: 9
# location: Milan, Rome, London
# time_zone: Amsterdam
# screen_name: elmaresearch
# name: Elma Research
# ====================================================================================
#
# the actual text of results[29]['text']
# retweet_count  = 6
# favorite_count = 0
# ...................
# RT @CureMelanoma: .@lululemon admits anti-sunscreen language is not research-based http://t.co/bB1v3Ljtkk #prevention #melanoma #skincancer
#
# the list of words ['rt', 'admits', 'anti-sunscreen', 'language', 'is', 'not', 'research-based']
# hashtags referenced ['prevention', 'melanoma', 'skincancer']
# twitter users mentioned ['curemelanoma', 'lululemon']
# URLs ['http://t.co/bb1v3ljtkk']
# AFINN sentiment score -1
# ............................
# description: stage 3A malignant melanoma...living for today, tomorrow is never promised
# followers_count: 550
# friends_count: 1632
# favourites_count: 2598
# location:
# time_zone: Hawaii
# screen_name: CarlaRake1
# name: Carla Rake
# ====================================================================================
#
# the actual text of results[30]['text']
# retweet_count  = 11
# favorite_count = 0
# ...................
# RT @Merck: Melanoma is the most dangerous form of skin cancer. Learn more and get tips to help protect yourself: http://t.co/1QmUg9TGwl #Me…
#
# the list of words ['rt', 'melanoma', 'is', 'the', 'most', 'dangerous', 'form', 'of', 'skin', 'cancer.', 'learn', 'more', 'and', 'get', 'tips', 'to', 'help', 'protect', 'yourself:']
# hashtags referenced ['me']
# twitter users mentioned ['merck']
# URLs ['http://t.co/1qmug9tgwl']
# AFINN sentiment score 3
# ............................
# description: Physiotherapist dx with Parkinson's disease 6 years ago, an avid advocate for PWP , Ambassador WPC 2016 , Portland ; Ambassador for Parkinson's Movement ,CPT UK
# followers_count: 308
# friends_count: 310
# favourites_count: 360
# location: Brentwood Bay BC Canada
# time_zone: None
# screen_name: JillianCarson7
# name: Jillian Carson
# ====================================================================================
#
# the actual text of results[31]['text']
# retweet_count  = 11
# favorite_count = 0
# ...................
# RT @Merck: Melanoma is the most dangerous form of skin cancer. Learn more and get tips to help protect yourself: http://t.co/1QmUg9TGwl #Me…
#
# the list of words ['rt', 'melanoma', 'is', 'the', 'most', 'dangerous', 'form', 'of', 'skin', 'cancer.', 'learn', 'more', 'and', 'get', 'tips', 'to', 'help', 'protect', 'yourself:']
# hashtags referenced ['me']
# twitter users mentioned ['merck']
# URLs ['http://t.co/1qmug9tgwl']
# AFINN sentiment score 3
# ............................
# description:
# followers_count: 181
# friends_count: 174
# favourites_count: 26
# location: St. Petersburg
# time_zone: Abu Dhabi
# screen_name: TimVetrov
# name: Timofey Vetrov
# ====================================================================================
#
# the actual text of results[32]['text']
# retweet_count  = 6
# favorite_count = 0
# ...................
# RT @CureMelanoma: .@lululemon admits anti-sunscreen language is not research-based http://t.co/bB1v3Ljtkk #prevention #melanoma #skincancer
#
# the list of words ['rt', 'admits', 'anti-sunscreen', 'language', 'is', 'not', 'research-based']
# hashtags referenced ['prevention', 'melanoma', 'skincancer']
# twitter users mentioned ['curemelanoma', 'lululemon']
# URLs ['http://t.co/bb1v3ljtkk']
# AFINN sentiment score -1
# ............................
# description: Dedicated to making Saskatchewan the healthiest province in Canada. Opinions are my own.
# followers_count: 191
# friends_count: 454
# favourites_count: 24
# location: Regina, SK
# time_zone: Saskatchewan
# screen_name: DonnaPCancer
# name: Donna Pasiechnik
# ====================================================================================
#
# the actual text of results[33]['text']
# retweet_count  = 6
# favorite_count = 0
# ...................
# RT @CureMelanoma: .@lululemon admits anti-sunscreen language is not research-based http://t.co/bB1v3Ljtkk #prevention #melanoma #skincancer
#
# the list of words ['rt', 'admits', 'anti-sunscreen', 'language', 'is', 'not', 'research-based']
# hashtags referenced ['prevention', 'melanoma', 'skincancer']
# twitter users mentioned ['curemelanoma', 'lululemon']
# URLs ['http://t.co/bb1v3ljtkk']
# AFINN sentiment score -1
# ............................
# description: We engage people from across Saskatchewan and show that tanning - whether it is baking in the sun or in a tanning bed - is harmful. Canadian Cancer Society
# followers_count: 154
# friends_count: 315
# favourites_count: 7
# location: Saskatchewan
# time_zone: None
# screen_name: TanFreeSK
# name: Tan Free Sask
# ====================================================================================
#
# the actual text of results[34]['text']
# retweet_count  = 6
# favorite_count = 0
# ...................
# RT @medical_xpress: New study helps scientists understand #melanoma development http://t.co/lcm7AucYp3 @universityofky
#
# the list of words ['rt', 'new', 'study', 'helps', 'scientists', 'understand', 'development']
# hashtags referenced ['melanoma']
# twitter users mentioned ['medical_xpress', 'universityofky']
# URLs ['http://t.co/lcm7aucyp3']
# AFINN sentiment score 2
# ............................
# description: Psalm 37:5.
# Dentistry student'14 - Universitat de Barcelona.
# followers_count: 358
# friends_count: 115
# favourites_count: 47
# location: ESPAÑA
# time_zone: None
# screen_name: MoGiller96
# name: Clo Matthew
# ====================================================================================
#
# the actual text of results[35]['text']
# retweet_count  = 6
# favorite_count = 0
# ...................
# RT @CureMelanoma: .@lululemon admits anti-sunscreen language is not research-based http://t.co/bB1v3Ljtkk #prevention #melanoma #skincancer
#
# the list of words ['rt', 'admits', 'anti-sunscreen', 'language', 'is', 'not', 'research-based']
# hashtags referenced ['prevention', 'melanoma', 'skincancer']
# twitter users mentioned ['curemelanoma', 'lululemon']
# URLs ['http://t.co/bb1v3ljtkk']
# AFINN sentiment score -1
# ............................
# description: Las Vegas Esthetician Blogging About All The In's & Out's Of Las Vegas Spa's & Salons &  Natural SkinCare Board Certified Oncology Esthetician! Spa Spa More Spa
# followers_count: 740
# friends_count: 1171
# favourites_count: 991
# location: LasVegasSpaGirl@blogspot.com
# time_zone: Pacific Time (US & Canada)
# screen_name: LasVegasSpaGirl
# name: LasVegasSpaGirl
# ====================================================================================
#
# the actual text of results[36]['text']
# retweet_count  = 6
# favorite_count = 0
# ...................
# RT @CureMelanoma: .@lululemon admits anti-sunscreen language is not research-based http://t.co/bB1v3Ljtkk #prevention #melanoma #skincancer
#
# the list of words ['rt', 'admits', 'anti-sunscreen', 'language', 'is', 'not', 'research-based']
# hashtags referenced ['prevention', 'melanoma', 'skincancer']
# twitter users mentioned ['curemelanoma', 'lululemon']
# URLs ['http://t.co/bb1v3ljtkk']
# AFINN sentiment score -1
# ............................
# description: Stage 3 Melanoma: it's not ''just'' skin cancer
# All views are my own
# followers_count: 56
# friends_count: 79
# favourites_count: 119
# location: Surrey, UK
# time_zone: None
# screen_name: backbaybrit
# name: Kate
# ====================================================================================
#
# the actual text of results[37]['text']
# retweet_count  = 11
# favorite_count = 0
# ...................
# RT @Merck: Melanoma is the most dangerous form of skin cancer. Learn more and get tips to help protect yourself: http://t.co/1QmUg9TGwl #Me…
#
# the list of words ['rt', 'melanoma', 'is', 'the', 'most', 'dangerous', 'form', 'of', 'skin', 'cancer.', 'learn', 'more', 'and', 'get', 'tips', 'to', 'help', 'protect', 'yourself:']
# hashtags referenced ['me']
# twitter users mentioned ['merck']
# URLs ['http://t.co/1qmug9tgwl']
# AFINN sentiment score 3
# ............................
# description: *Design/Industrial Mfg & Real Estate background *Equity Mkt Investor *Occasional Trader. *Photography *German Car Fan *Golf *Cycling *Sports
# followers_count: 580
# friends_count: 415
# favourites_count: 2029
# location: Cleveland, OH
# time_zone: Eastern Time (US & Canada)
# screen_name: Ktr8der
# name: Kevin
# ====================================================================================
#
# the actual text of results[38]['text']
# retweet_count  = 11
# favorite_count = 0
# ...................
# RT @Merck: Melanoma is the most dangerous form of skin cancer. Learn more and get tips to help protect yourself: http://t.co/1QmUg9TGwl #Me…
# the list of words ['rt', 'melanoma', 'is', 'the', 'most', 'dangerous', 'form', 'of', 'skin', 'cancer.', 'learn', 'more', 'and', 'get', 'tips', 'to', 'help', 'protect', 'yourself:']
# hashtags referenced ['me']
# twitter users mentioned ['merck']
# URLs ['http://t.co/1qmug9tgwl']
# AFINN sentiment score 3
# ............................
# description: I am a Business Boy in pharma & healthcare organizations..
# followers_count: 1190
# friends_count: 1391
# favourites_count: 16
# location: India
# time_zone: None
# screen_name: call2shridhar
# name: shridhar mishra
# ====================================================================================
#
# the actual text of results[39]['text']
# retweet_count  = 11
# favorite_count = 0
# ...................
# RT @Merck: Melanoma is the most dangerous form of skin cancer. Learn more and get tips to help protect yourself: http://t.co/1QmUg9TGwl #Me…
#
# the list of words ['rt', 'melanoma', 'is', 'the', 'most', 'dangerous', 'form', 'of', 'skin', 'cancer.', 'learn', 'more', 'and', 'get', 'tips', 'to', 'help', 'protect', 'yourself:']
# hashtags referenced ['me']
# twitter users mentioned ['merck']
# URLs ['http://t.co/1qmug9tgwl']
# AFINN sentiment score 3
# ............................
# description: Wife, mom, and advocate for people with Down syndrome & others with special needs.  Works to connect people who need with people who can to get things done.
# followers_count: 20
# friends_count: 72
# favourites_count: 440
# location:
# time_zone: None
# screen_name: jmgerhart
# name: Julie Gerhart
# ====================================================================================
#
# the actual text of results[40]['text']
# retweet_count  = 11
# favorite_count = 0
# ...................
# RT @Merck: Melanoma is the most dangerous form of skin cancer. Learn more and get tips to help protect yourself: http://t.co/1QmUg9TGwl #Me…
#
# the list of words ['rt', 'melanoma', 'is', 'the', 'most', 'dangerous', 'form', 'of', 'skin', 'cancer.', 'learn', 'more', 'and', 'get', 'tips', 'to', 'help', 'protect', 'yourself:']
# hashtags referenced ['me']
# twitter users mentioned ['merck']
# URLs ['http://t.co/1qmug9tgwl']
# AFINN sentiment score 3
# ............................
# description: Ingeniero en Biotecnología
# followers_count: 83
# friends_count: 152
# favourites_count: 362
# location:
# time_zone: None
# screen_name: rodga90
# name: Rodrigo Garibay
# ====================================================================================
#
# the actual text of results[41]['text']
# retweet_count  = 11
# favorite_count = 3
# ...................
# Melanoma is the most dangerous form of skin cancer. Learn more and get tips to help protect yourself: http://t.co/1QmUg9TGwl #MerckOncology
#
# the list of words ['melanoma', 'is', 'the', 'most', 'dangerous', 'form', 'of', 'skin', 'cancer.', 'learn', 'more', 'and', 'get', 'tips', 'to', 'help', 'protect', 'yourself:']
# hashtags referenced ['merckoncology']
# twitter users mentioned []
# URLs ['http://t.co/1qmug9tgwl']
# AFINN sentiment score 3
# ............................
# description: Merck's official Twitter handle. Intended for US residents only. Tweeting about our commitment to saving & improving lives. http://t.co/xTHnju5Z
# followers_count: 38692
# friends_count: 707
# favourites_count: 126
# location: Whitehouse Station, NJ
# time_zone: Eastern Time (US & Canada)
# screen_name: Merck
# name: Merck
# ====================================================================================
#
# the actual text of results[42]['text']
# retweet_count  = 6
# favorite_count = 3
# ...................
# .@lululemon admits anti-sunscreen language is not research-based http://t.co/bB1v3Ljtkk #prevention #melanoma #skincancer
#
# the list of words ['admits', 'anti-sunscreen', 'language', 'is', 'not', 'research-based']
# hashtags referenced ['prevention', 'melanoma', 'skincancer']
# twitter users mentioned ['lululemon']
# URLs ['http://t.co/bb1v3ljtkk']
# AFINN sentiment score -1
# ............................
# description: The Melanoma Research Foundation (MRF) is the largest independent organization devoted to #melanoma. Help us find pathways to a cure!
# followers_count: 6910
# friends_count: 1652
# favourites_count: 339
# location: Washington, DC & Worldwide
# time_zone: Eastern Time (US & Canada)
# screen_name: CureMelanoma
# name: MelanomaResearchFdn
# ====================================================================================
#
# the actual text of results[43]['text']
# retweet_count  = 26
# favorite_count = 0
# ...................
# RT @Walmart: Join @BowesDerm, @itsgabrielleu &amp; @sandraecheverr now for #ChooseSkinHealth &amp; learn more on melanoma. #Neutrogena http://t.co/…
#
# the list of words ['rt', 'join', 'now', 'for', 'learn', 'more', 'on', 'melanoma.']
# hashtags referenced ['chooseskinhealth', 'neutrogena']
# twitter users mentioned ['walmart', 'bowesderm', 'itsgabrielleu', 'sandraecheverr']
# URLs ['http://t.co/']
# AFINN sentiment score 1
# ............................
# description: Amo a @mayrinvillanew @MarjoDSousa @sandraecheverr y @davidzepeda1.Para mi son los mejores .Mi mejor amiga es @FlorRoxana8 .★★★
# followers_count: 456
# friends_count: 998
# favourites_count: 642
# location:
# time_zone: Athens
# screen_name: nicoleta_07
# name: Nikki ♥
# ====================================================================================
#
# the actual text of results[44]['text']
# retweet_count  = 4
# favorite_count = 0
# ...................
# RT @MelanomaReAlli: Are you going to @IdolsLiveTour? For every ticket purchased @AmericanIdol donates $1 to MRA to help cure #melanoma. htt…
#
# the list of words ['rt', 'are', 'you', 'going', 'to', 'for', 'every', 'ticket', 'purchased', 'donates', '$1', 'to', 'mra', 'to', 'help', 'cure', 'htt\xe2\x80\xa6']
# hashtags referenced ['melanoma']
# twitter users mentioned ['melanomarealli', 'idolslivetour', 'americanidol']
# URLs []
# AFINN sentiment score 2
# ............................
# description: Dedicated to the health of Stage 1 & 2 melanoma patients. Tweets by our team at Castle Biosciences, a developer of molecular tests for rare cancers.
# followers_count: 237
# friends_count: 148
# favourites_count: 12
# location:
# time_zone: None
# screen_name: SkinMelanoma
# name: SKIN MELANOMA
# ====================================================================================
# twitter_functions.py:346: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if word in ['.',':','!',',',';',"-","-","?",'\xe2\x80\xa6',"!","&amp;","|"]: continue

# %% [markdown]
# # Let's do a quick lexical analysis of these tweets

# %% [markdown]
# ####Step 1: Collect all the tweets in one string
#
# Note: the AFINN score will be for the entire string, which may or may not be helpful

# %%
tweets = ""
for i in range(num_tweets):
    tweets = tweets + " " + results[i]['text']

words, hashes, users, urls, AFINN_score = parse_tweet_text(tweets, AFINN=True)

print "AFINN sentiment score %d"%AFINN_score
# Out:
# AFINN sentiment score 31

# %% [markdown]
# ####Step 2: Remove the stop words
#
# Note: English stop words won't help in Espanish

# %%
from nltk.corpus import stopwords

stop = stopwords.words('english')
stop.append("it's")
stop.append('w/')

filtered_word_list = [word for word in words if word not in stop]
filtered_word_set  = set(filtered_word_list)

print "%d  total words"%len(filtered_word_list)
print "%d unique words"%len(filtered_word_set)
# Out:
# 416  total words
# 58 unique words

# %% [markdown]
# ####Step 3: Show the top 10 of each entity type
#
# Note: 'rt' means retweet and it's very common, but you may not consider it a word

# %%
from collections import Counter
from prettytable import PrettyTable

for label, data in (('Word', filtered_word_list), 
                    ('Senders', senders), 
                    ('Users Mentioned', users),
                    ('Hashtag', hashes),
                    ('URL', urls)):
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print pt
# Out:
# +----------+-------+
# | Word     | Count |
# +----------+-------+
# | rt       |    41 |
# | skin     |    23 |
# | form     |    23 |
# | melanoma |    21 |
# | help     |    15 |
# | learn    |    13 |
# | cancer.  |    12 |
# | tips     |    12 |
# | get      |    12 |
# | protect  |    12 |
# +----------+-------+
# +----------------------+-------+
# | Senders              | Count |
# +----------------------+-------+
# | Marlene Hernandez    |     1 |
# | National Cancer Inst |     1 |
# | SKIN MELANOMA        |     1 |
# | Mustafa O. Guler     |     1 |
# | shridhar mishra      |     1 |
# | Amanda Kelly Silbs   |     1 |
# | Quorum Review - IRB  |     1 |
# | Tan Free Sask        |     1 |
# | Matt Ellefson        |     1 |
# | Merck                |     1 |
# +----------------------+-------+
# +-----------------+-------+
# | Users Mentioned | Count |
# +-----------------+-------+
# | merck           |    11 |
# | thenci          |    10 |
# | lululemon       |     9 |
# | racecancer      |     7 |
# | longtrailbeer   |     7 |
# | curemelanoma    |     6 |
# | bostontweet     |     6 |
# | idolslivetour   |     3 |
# | americanidol    |     3 |
# | melanomarealli  |     3 |
# +-----------------+-------+
# +------------------+-------+
# | Hashtag          | Count |
# +------------------+-------+
# | melanoma         |    12 |
# | me               |    11 |
# | skincancer       |     7 |
# | prevention       |     7 |
# | chooseskinhealth |     1 |
# | clinicaltrials   |     1 |
# | merckoncology    |     1 |
# | neutrogena       |     1 |
# +------------------+-------+
# +------------------------+-------+
# | URL                    | Count |
# +------------------------+-------+
# | http://t.co/1qmug9tgwl |    12 |
# | http://t.co/mhx2k7lpfg |    11 |
# | http://t.co/tz3n1tucmh |    11 |
# | http://t.co/bb1v3ljtkk |     7 |
# | http://t.co/gzbve91xdb |     2 |
# | http://t.co/kfrpyujv6b |     1 |
# | http://t.co/           |     1 |
# | http://t.co/lcm7aucyp3 |     1 |
# | http://t.co/guqufwr    |     1 |
# | http://t.co/brp7mc7xes |     1 |
# +------------------------+-------+

# %% [markdown]
# ####Step 4: Lexical Diversity

# %%
from twitter_functions import lexical_diversity, average_words

print "Lexical Diversity"
print "words  %0.2f"%lexical_diversity(set(words), words) # words not filtered_word_list
print "hashes %0.2f"%lexical_diversity(set(hashes), hashes)
print "users  %0.2f"%lexical_diversity(set(users), users)
print "urls   %0.2f"%lexical_diversity(set(urls), urls)

print "\nAverage per tweet"
print "words           %0.2f"%average_words(words, num_tweets)
print "filtered words  %0.2f"%average_words(filtered_word_list, num_tweets)
print "hashes          %0.2f"%average_words(hashes, num_tweets)
print "users           %0.2f"%average_words(users, num_tweets)
print "urls            %0.2f"%average_words(urls, num_tweets)
# Out:
# Lexical Diversity
# words  0.12
# hashes 0.20
# users  0.24
# urls   0.21
#
# Average per tweet
# words           14.60
# filtered words  9.24
# hashes          0.91
# users           1.64
# urls            1.07

# %% [markdown]
# ####Step 5: Can't finish without a word cloud, right?
#
# Note 1: foreign-language codes often cause this to fail.
#
# Note 2: the lexical density determines the look of the result: a few words in a mass of many infrequent words makes for a more attractive picture. Playing with the numerical parameter to num_tags also has an effect.

# %%
from pytagcloud import create_tag_image, make_tags
import IPython.display

# 'rt' is very common and useless
filter_ex_rt = list(filtered_word_list)
while 'rt' in filter_ex_rt: filter_ex_rt.remove('rt')

for item in [filter_ex_rt]:
    c = Counter(item)

num_tags = min(75, len(c.most_common())-1)
tags     = make_tags(c.most_common()[:num_tags], maxsize=120)

create_tag_image(tags, 'wordcloud.png', size=(900,900), fontname='Lobster' )

IPython.display.display(IPython.display.Image(filename='wordcloud.png'))
