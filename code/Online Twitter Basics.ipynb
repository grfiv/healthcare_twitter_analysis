# %% [markdown]
# Online Twitter Basics
# ======================

# %% [markdown]
# ###This notebook goes step-by-step through logging onto Twitter, live, retrieving tweets by keyword and analyzing them.
#
# My thanks to Bill Howe of the University of Washington for his Coursera course *Introduction to Data Analysis* and Matthew A. Russell for his book *Mining the Social Web* for getting me started.
#
# Note 1: I run the IPython notebook in pylab=inline mode which makes it look like Matlab; this may mean that you will have to explicitly `import` some modules that I take for granted. Alternatively, you could configure yourself for pylab, which I obviously think is better.
#
# Note 2: Twitter very popular outside the United States. Many non-English languages have codesets that I don't handle properly leading to program failures. Keep calm and carry on: at worst, you'll have to restart the kernel.

# %% [markdown]
# ### Logon to Twitter

# %% [markdown]
# I have my Twitter credentials in a file `twitter_credential.py` ... you need to create your own as follows:
# ```python
# def twitter_credentials():
#     """
#     Generate your own Twitter credentials here:  https://apps.twitter.com/
#     """
#     api_key = " "
#     api_secret = " "
#
#     access_token_key = " "
#     access_token_secret = " "
#
#     return (api_key, api_secret, access_token_key, access_token_secret)
# ```

# %% [markdown]
# If you get a message similar to `<twitter.api.Twitter object at 0x000000000E79AAC8>`, you've succesfully signed on

# %%
from twitter_credentials import twitter_credentials # my credentials
token, token_secret, consumer_key, consumer_secret = twitter_credentials()

import oauth2 as oauth
import urllib2 as urllib
import twitter

auth = twitter.oauth.OAuth(consumer_key, consumer_secret, token, token_secret)

twitter_api = twitter.Twitter(auth=auth)
print twitter_api
# Out:
# <twitter.api.Twitter object at 0x0000000010808B70>

# %% [markdown]
# ###QT Console
# I like to run the qtconsole whenever I am using a notebook because it allows me to experiment on a command-line interface to the notebook's session, with all its current variables, etc.

# %%
# %qtconsole

# %% [markdown]
# ###`twitter_functions.py`
# I have a file `twitter_functions.py` that contains a number of utility functions. Find it on my GitHub repo: [grfiv/healthcare_twitter_analysis](https://github.com/grfiv/healthcare_twitter_analysis)
#
# You also need to have the `AFINN-111.txt` sentiment-word file installed.
#
# A note on `AFINN-111.txt`: the file has a tab delimiter separating words and phrases and their score. You can add your own n-grams as long as you retain the formatting. I strip out extra white space in phrases so you don't have to be exact in that regard. The sentiment score is simply the sum of the scores of any n-grams found in the text after urls, hashtags and users have been removed.

# %% [markdown]
# ### Make a simple query

# %% [markdown]
# Modify the word or phrase in `q = " ... "`. Only one term.
# Try changing `num_tweet_request`, too.

# %%
import json
from twitter_functions import twitter_search

num_tweet_request = 250

q = "Lung Cancer"
initial_results = twitter_search(twitter_api, q, max_results = num_tweet_request)

# %% [markdown]
# ### Filter by `retweet_count`

# %% [markdown]
# The idea is that the the best tweets are ones that have been retweeted. So we will keep only those tweets that have a `retweet_count` greater than some threshold.
#
# `favorite_count` is also supposed to have some bearing on importance but it's usually zero in the ones I've looked at.

# %%
retweet_threshold = 3

results = [tweet 
           for tweet in initial_results 
           if tweet['retweet_count'] > retweet_threshold]

num_tweets = len(results)
print "%d tweets received"%len(initial_results)
print "%d tweets after retweet filtering"%len(results)
# Out:
# 200 tweets received
# 56 tweets after retweet filtering

# %% [markdown]
# ### Display the raw json returned for one of the `num_tweets` results we asked for

# %%
# I commented this out because the list is very long
# However, to do any serious Twitter munging, you need to know all about this thing

#print json.dumps(results[1], indent=4)

# %% [markdown]
# ###Parse the 'text' field, which is the body of the tweet, for each of the `num_tweets` responses returned
# I use my utility function `parse_tweet_text` for the body of the tweet itself; it also returns the AFINN sentiment, for which you must have `AFINN-111.txt` installed. I parse the json directly for the other fields.
#
# A response of `[]` means nothing was returned for a particular 'entity'.

# %%
from twitter_functions import parse_tweet_text 

senders = []
for i in range(num_tweets):
    senders.append(results[i]['user']['name'])
    
    tweet_text = results[i]['text']
    words, hashes, users, urls, AFINN_score = parse_tweet_text(tweet_text, AFINN=True)

    print "the actual text of results[%d]['text']\nretweet_count  = %d\nfavorite_count = %d\n...................\n%s"%(i,results[i]['retweet_count'],results[i]['favorite_count'],tweet_text)
    print "\nthe list of words %s"%[word.encode('utf-8') for word in words]
    print "hashtags referenced %s"%[hash_.encode('utf-8') for hash_ in hashes]
    print "twitter users mentioned %s"%[user.encode('utf-8') for user in users]
    print "URLs %s"%[url.encode('utf-8') for url in urls]
    print "AFINN sentiment score %d"%AFINN_score
    print "............................"
    print "description: %s"%results[i]['user']['description']
    print "followers_count: %d"%results[i]['user']['followers_count']
    print "friends_count: %d"%results[i]['user']['friends_count']
    print "favourites_count: %d"%results[i]['user']['favourites_count']
    print "location: %s"%results[i]['user']['location']
    print "time_zone: %s"%results[i]['user']['time_zone']
    print "screen_name: %s"%results[i]['user']['screen_name']
    print "name: %s"%results[i]['user']['name']
    if results[i]['place'] is not None: print "place: %s"%results[i]['place']
    print "====================================================================================\n"
# Out:
# the actual text of results[0]['text']
# retweet_count  = 25
# favorite_count = 0
# ...................
# RT @tanya_plibersek: "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# …
#
# the list of words ['rt', '"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned ['tanya_plibersek']
# URLs []
# AFINN sentiment score 2
# ............................
# description: Mixed media artist resulting in mixed results. Movie mad, mad for politics and the best friend Newscorp ever had.
# followers_count: 48
# friends_count: 182
# favourites_count: 121
# location: Sydney Australia
# time_zone: None
# screen_name: james_powditch
# name: James Powditch
# ====================================================================================
#
# the actual text of results[1]['text']
# retweet_count  = 25
# favorite_count = 0
# ...................
# RT @tanya_plibersek: "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# …
#
# the list of words ['rt', '"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned ['tanya_plibersek']
# URLs []
# AFINN sentiment score 2
# ............................
# description:
# followers_count: 159
# friends_count: 98
# favourites_count: 628
# location:
# time_zone: Sydney
# screen_name: suelynne12
# name: Marie E Wagner
# ====================================================================================
#
# the actual text of results[2]['text']
# retweet_count  = 25
# favorite_count = 0
# ...................
# RT @tanya_plibersek: "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# …
#
# the list of words ['rt', '"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned ['tanya_plibersek']
# URLs []
# AFINN sentiment score 2
# ............................
# description: Tanya Plibersek for Prime Minister.
# followers_count: 0
# friends_count: 16
# favourites_count: 0
# location:
# time_zone: Melbourne
# screen_name: TeamPlibersek
# name: Team Plibersek
# ====================================================================================
#
# the actual text of results[3]['text']
# retweet_count  = 25
# favorite_count = 0
# ...................
# RT @tanya_plibersek: "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# …
#
# the list of words ['rt', '"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned ['tanya_plibersek']
# URLs []
# AFINN sentiment score 2
# ............................
# description: Also answers to Bacteria King Cowboy Grain. O negligence! Fit for a fool to fall by
# followers_count: 112
# friends_count: 244
# favourites_count: 327
# location:
# time_zone: Brisbane
# screen_name: bradboyqld
# name: Sir Wecarealot
# ====================================================================================
#
# the actual text of results[4]['text']
# retweet_count  = 25
# favorite_count = 0
# ...................
# RT @tanya_plibersek: "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# …
#
# the list of words ['rt', '"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned ['tanya_plibersek']
# URLs []
# AFINN sentiment score 2
# ............................
# description: #gotiges
# followers_count: 118
# friends_count: 261
# favourites_count: 624
# location: Wait Awhile
# time_zone: Perth
# screen_name: w_nn_b_y_v_w_l
# name: Luke
# ====================================================================================
#
# the actual text of results[5]['text']
# retweet_count  = 25
# favorite_count = 0
# ...................
# RT @tanya_plibersek: "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# …
#
# the list of words ['rt', '"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned ['tanya_plibersek']
# URLs []
# AFINN sentiment score 2
# ............................
# description: Just call me Madam. While I try to ensure tweets are true, necessary and mostly kind but sometimes this is impossible!
# followers_count: 236
# friends_count: 988
# favourites_count: 1405
# location: Byron Bay, Australia
# time_zone: Melbourne
# screen_name: wingfield
# name: Madam Dee Baker
# ====================================================================================
#
# the actual text of results[6]['text']
# retweet_count  = 25
# favorite_count = 0
# ...................
# RT @tanya_plibersek: "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# …
#
# the list of words ['rt', '"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned ['tanya_plibersek']
# URLs []
# AFINN sentiment score 2
# ............................
# description:
# followers_count: 48
# friends_count: 551
# favourites_count: 11
# location: Sydney, Australia
# time_zone: Sydney
# screen_name: MarkLuton1
# name: Mark Luton
# ====================================================================================
#
# the actual text of results[7]['text']
# retweet_count  = 25
# favorite_count = 0
# ...................
# RT @tanya_plibersek: "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# …
#
# the list of words ['rt', '"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned ['tanya_plibersek']
# URLs []
# AFINN sentiment score 2
# ............................
# description: The Political Institute
# followers_count: 468
# friends_count: 775
# favourites_count: 144
# location:
# time_zone: Sydney
# screen_name: BobNew8
# name: Bob New
# ====================================================================================
#
# the actual text of results[8]['text']
# retweet_count  = 25
# favorite_count = 0
# ...................
# RT @tanya_plibersek: "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# …
#
# the list of words ['rt', '"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned ['tanya_plibersek']
# URLs []
# AFINN sentiment score 2
# ............................
# description:
# followers_count: 121
# friends_count: 128
# favourites_count: 1596
# location: Adelaide South Australia
# time_zone: Adelaide
# screen_name: MariaMatthews5
# name: Maria Matthews
# ====================================================================================
#
# the actual text of results[9]['text']
# retweet_count  = 25
# favorite_count = 0
# ...................
# RT @tanya_plibersek: "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# …
#
# the list of words ['rt', '"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned ['tanya_plibersek']
# URLs []
# AFINN sentiment score 2
# ............................
# description: Political adviser, senior public servant, political scientist, comms strategist - lover of art, philosophy, literature, baseball, football and food
# followers_count: 372
# friends_count: 1293
# favourites_count: 1089
# location: Sydney
# time_zone: Brisbane
# screen_name: tcookAU
# name: trevorcook
# ====================================================================================
#
# the actual text of results[10]['text']
# retweet_count  = 25
# favorite_count = 0
# ...................
# RT @tanya_plibersek: "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# …
#
# the list of words ['rt', '"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned ['tanya_plibersek']
# URLs []
# AFINN sentiment score 2
# ............................
# description: Not as World Famous as I used to be.  Considering my options.
# followers_count: 360
# friends_count: 582
# favourites_count: 43
# location:
# time_zone: London
# screen_name: twf_mike
# name: Mike Roberts
# ====================================================================================
#
# the actual text of results[11]['text']
# retweet_count  = 25
# favorite_count = 0
# ...................
# RT @tanya_plibersek: "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# …
#
# the list of words ['rt', '"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned ['tanya_plibersek']
# URLs []
# AFINN sentiment score 2
# ............................
# description: Recruitment Manager - Aged Care Advocate - Specialist Internal, Agency and Rec2Rec Recruitment professional
# followers_count: 347
# friends_count: 785
# favourites_count: 129
# location: Sydney - Australia
# time_zone: None
# screen_name: craigacole
# name: Craig Cole
# ====================================================================================
#
# the actual text of results[12]['text']
# retweet_count  = 25
# favorite_count = 0
# ...................
# RT @tanya_plibersek: "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# …
#
# the list of words ['rt', '"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned ['tanya_plibersek']
# URLs []
# AFINN sentiment score 2
# ............................
# description: Rome burns, the emperor plays his violin, i sit at his feet and write a thinkpiece about the inevitable twitter/tumblr backlash
# followers_count: 1592
# friends_count: 2001
# favourites_count: 3743
# location: caitlinxwelsh@gmail.com
# time_zone: Hawaii
# screen_name: Caitlin_Welsh
# name: Caitlin Welsh
# ====================================================================================
#
# the actual text of results[13]['text']
# retweet_count  = 25
# favorite_count = 0
# ...................
# RT @tanya_plibersek: "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# …
# the list of words ['rt', '"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned ['tanya_plibersek']
# URLs []
# AFINN sentiment score 2
# ............................
# description: Retired UK private Investigator. Disillusioned with the investigative qualities of today's media.
# followers_count: 337
# friends_count: 475
# favourites_count: 1808
# location: Melbourne
# time_zone: None
# screen_name: EricHardcastle
# name: eric hardcastle
# ====================================================================================
#
# the actual text of results[14]['text']
# retweet_count  = 25
# favorite_count = 0
# ...................
# RT @tanya_plibersek: "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# …
#
# the list of words ['rt', '"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned ['tanya_plibersek']
# URLs []
# AFINN sentiment score 2
# ............................
# description: Interests: Politics (Port Winger), Collecting Civil & Military Aviation Books & Ephemera
# followers_count: 1835
# friends_count: 1997
# favourites_count: 77965
# location: The Goldfields
# time_zone: Melbourne
# screen_name: geoffrey_payne
# name: Geoffrey Payne
# ====================================================================================
#
# the actual text of results[15]['text']
# retweet_count  = 25
# favorite_count = 0
# ...................
# RT @tanya_plibersek: "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# …
#
# the list of words ['rt', '"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned ['tanya_plibersek']
# URLs []
# AFINN sentiment score 2
# ............................
# description:
# followers_count: 77
# friends_count: 323
# favourites_count: 534
# location: Pambula NSW
# time_zone: Canberra
# screen_name: rodp48
# name: Rodp48
# ====================================================================================
#
# the actual text of results[16]['text']
# retweet_count  = 25
# favorite_count = 0
# ...................
# RT @tanya_plibersek: "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# …
#
# the list of words ['rt', '"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned ['tanya_plibersek']
# URLs []
# AFINN sentiment score 2
# ............................
# description: Executive Director of Mobile at The Pants Institute. Former Crystallographer, now iOS developer.
# Currently plying my trade at a new media startup in Pyrmont.
# followers_count: 725
# friends_count: 904
# favourites_count: 1252
# location: Wentworth Falls, Australia
# time_zone: Sydney
# screen_name: corduroy
# name: Joshua McKinnon
# ====================================================================================
#
# the actual text of results[17]['text']
# retweet_count  = 4
# favorite_count = 0
# ...................
# RT @DrFrankBeard: Plunge in smoking attributed to plain packaging - likened to finding a vaccine against lung cancer http://t.co/HkoX92g4OC…
#
# the list of words ['rt', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging', 'likened', 'to', 'finding', 'a', 'vaccine', 'against', 'lung', 'cancer']
# hashtags referenced []
# twitter users mentioned ['drfrankbeard']
# URLs ['http://t.co/hkox92g4oc']
# AFINN sentiment score -1
# ............................
# description: Interests: Politics (Port Winger), Collecting Civil & Military Aviation Books & Ephemera
# followers_count: 1835
# friends_count: 1997
# favourites_count: 77965
# location: The Goldfields
# time_zone: Melbourne
# screen_name: geoffrey_payne
# name: Geoffrey Payne
# ====================================================================================
#
# the actual text of results[18]['text']
# retweet_count  = 25
# favorite_count = 0
# ...................
# RT @tanya_plibersek: "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# …
#
# the list of words ['rt', '"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned ['tanya_plibersek']
# URLs []
# AFINN sentiment score 2
# ............................
# description: Mother of three, destroying the joint, frightbat
# followers_count: 1285
# friends_count: 213
# favourites_count: 28437
# location:
# time_zone: None
# screen_name: mackaysuzie
# name: Susan Mackay
# ====================================================================================
#
# the actual text of results[19]['text']
# retweet_count  = 25
# favorite_count = 0
# ...................
# RT @tanya_plibersek: "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# …
#
# the list of words ['rt', '"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned ['tanya_plibersek']
# URLs []
# AFINN sentiment score 2
# ............................
# description: Every Saree has a story : Read an extract here - http://t.co/RWa8JOVSzI
# followers_count: 1055
# friends_count: 622
# favourites_count: 9057
# location: Melbourne
# time_zone: None
# screen_name: SuDharmapala
# name: MahaRani of Rantipop
# ====================================================================================
#
# the actual text of results[20]['text']
# retweet_count  = 25
# favorite_count = 0
# ...................
# RT @tanya_plibersek: "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# …
#
# the list of words ['rt', '"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned ['tanya_plibersek']
# URLs []
# AFINN sentiment score 2
# ............................
# description: Wish I was in Bonnieux
# followers_count: 146
# friends_count: 256
# favourites_count: 36
# location: Australia
# time_zone: Sydney
# screen_name: quotethon
# name: Dame Jennifer of Oz
# ====================================================================================
#
# the actual text of results[21]['text']
# retweet_count  = 25
# favorite_count = 0
# ...................
# RT @tanya_plibersek: "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# …
#
# the list of words ['rt', '"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned ['tanya_plibersek']
# URLs []
# AFINN sentiment score 2
# ............................
# description: Devourer of media. Lam baster of Lying Stupid Politicians. General life Philosopher. With just a twist of Absinthe.
# followers_count: 404
# friends_count: 174
# favourites_count: 8819
# location: Lat/Long: -32.77, 152.0697
# time_zone: None
# screen_name: beestydi
# name: DIANNE  ANNA BAY
# ====================================================================================
#
# the actual text of results[22]['text']
# retweet_count  = 25
# favorite_count = 0
# ...................
# RT @tanya_plibersek: "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# …
#
# the list of words ['rt', '"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned ['tanya_plibersek']
# URLs []
# AFINN sentiment score 2
# ............................
# description: UNSW Water Quality Researcher. Associate Professor in Environmental Engineering.
# followers_count: 606
# friends_count: 279
# favourites_count: 171
# location: Sydney
# time_zone: Sydney
# screen_name: stukhan
# name: Stuart Khan
# ====================================================================================
#
# the actual text of results[23]['text']
# retweet_count  = 25
# favorite_count = 0
# ...................
# RT @tanya_plibersek: "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# …
#
# the list of words ['rt', '"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned ['tanya_plibersek']
# URLs []
# AFINN sentiment score 2
# ............................
# description: By and large, language is a tool for concealing the truth..........George Carlin
# followers_count: 1867
# friends_count: 1768
# favourites_count: 9158
# location:
# time_zone: None
# screen_name: toninicho
# name: Dame Frightbat
# ====================================================================================
#
# the actual text of results[24]['text']
# retweet_count  = 25
# favorite_count = 0
# ...................
# RT @tanya_plibersek: "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# …
# the list of words ['rt', '"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned ['tanya_plibersek']
# URLs []
# AFINN sentiment score 2
# ............................
# description: Current affairs whore
# followers_count: 54
# friends_count: 399
# favourites_count: 20
# location: Bowral NSW Australia
# time_zone: Sydney
# screen_name: Nigellusk
# name: Nigel Lusk
# ====================================================================================
#
# the actual text of results[25]['text']
# retweet_count  = 25
# favorite_count = 22
# ...................
# "It's almost like finding a vaccine that works against lung cancer." Plunge in smoking attributed to plain packaging.
# http://t.co/QZ0Ar8vq6D
#
# the list of words ['"it\'s', 'almost', 'like', 'finding', 'a', 'vaccine', 'that', 'works', 'against', 'lung', 'cancer."', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging.']
# hashtags referenced []
# twitter users mentioned []
# URLs ['http://t.co/qz0ar8vq6d']
# AFINN sentiment score 2
# ............................
# description: Deputy Leader of the Opposition, Shadow Minister for Foreign Affairs + International Development in the Australian Parliament. RTs do not equal endorsements.
# followers_count: 54940
# friends_count: 456
# favourites_count: 7
# location: Sydney
# time_zone: Sydney
# screen_name: tanya_plibersek
# name: Tanya Plibersek
# ====================================================================================
#
# the actual text of results[26]['text']
# retweet_count  = 47
# favorite_count = 0
# ...................
# RT @theNCI: Secondhand smoke causes lung cancer in nonsmokers; there's no safe level of exposure to secondhand smoke: http://t.co/TUupQZStGo
#
# the list of words ['rt', 'secondhand', 'smoke', 'causes', 'lung', 'cancer', 'in', 'nonsmokers;', "there's", 'no', 'safe', 'level', 'of', 'exposure', 'to', 'secondhand', 'smoke:']
# hashtags referenced []
# twitter users mentioned ['thenci']
# URLs ['http://t.co/tuupqzstgo']
# AFINN sentiment score -1
# ............................
# description: Proud mother of a beautiful and strong minded daughter. Nurse and Clinical Researcher looking for the next wonder drug daily
# followers_count: 66
# friends_count: 118
# favourites_count: 4
# location:
# time_zone: Quito
# screen_name: CrazyCarrera
# name: Amanda Carrera
# ====================================================================================
#
# the actual text of results[27]['text']
# retweet_count  = 5
# favorite_count = 0
# ...................
# RT @ShockingFactsz: Lung cancer was how the cigarette company Marlboro’s first owner died.
#
# the list of words ['rt', 'lung', 'cancer', 'was', 'how', 'the', 'cigarette', 'company', 'marlboro\xe2\x80\x99s', 'first', 'owner', 'died.']
# hashtags referenced []
# twitter users mentioned ['shockingfactsz']
# URLs []
# AFINN sentiment score -1
# ............................
# description: Happy & Contented
# followers_count: 129
# friends_count: 190
# favourites_count: 1456
# location: PH
# time_zone: Beijing
# screen_name: aangelestrella
# name: ANGEL
# ====================================================================================
#
# the actual text of results[28]['text']
# retweet_count  = 4
# favorite_count = 0
# ...................
# RT @Rosaaaa05: You're 15. You should be trying to get a life instead of trying to get lung cancer.
#
# the list of words ['rt', "you're", '15.', 'you', 'should', 'be', 'trying', 'to', 'get', 'a', 'life', 'instead', 'of', 'trying', 'to', 'get', 'lung', 'cancer.']
# hashtags referenced []
# twitter users mentioned ['rosaaaa05']
# URLs []
# AFINN sentiment score 0
# ............................
# description: Hopes and fears.
# followers_count: 382
# friends_count: 264
# favourites_count: 13167
# location: rock 'n roll hall of shame
# time_zone: None
# screen_name: janc0na
# name: jayda.
# ====================================================================================
#
# the actual text of results[29]['text']
# retweet_count  = 4
# favorite_count = 0
# ...................
# RT @Rosaaaa05: You're 15. You should be trying to get a life instead of trying to get lung cancer.
#
# the list of words ['rt', "you're", '15.', 'you', 'should', 'be', 'trying', 'to', 'get', 'a', 'life', 'instead', 'of', 'trying', 'to', 'get', 'lung', 'cancer.']
# hashtags referenced []
# twitter users mentioned ['rosaaaa05']
# URLs []
# AFINN sentiment score 0
# ............................
# description: Volleyball & Softball are life
# followers_count: 605
# friends_count: 575
# favourites_count: 11190
# location: Lewisville
# time_zone: None
# screen_name: EmilyTidwell1
# name: Juvenile
# ====================================================================================
#
# the actual text of results[30]['text']
# retweet_count  = 5
# favorite_count = 0
# ...................
# RT @ShockingFactsz: Lung cancer was how the cigarette company Marlboro’s first owner died.
#
# the list of words ['rt', 'lung', 'cancer', 'was', 'how', 'the', 'cigarette', 'company', 'marlboro\xe2\x80\x99s', 'first', 'owner', 'died.']
# hashtags referenced []
# twitter users mentioned ['shockingfactsz']
# URLs []
# AFINN sentiment score -1
# ............................
# description: dat fufu lame shit i aint widdit gratata
# followers_count: 233
# friends_count: 209
# favourites_count: 2047
# location: neverland
# time_zone: Hong Kong
# screen_name: hnlmw
# name: cheese burger.
# ====================================================================================
#
# the actual text of results[31]['text']
# retweet_count  = 6
# favorite_count = 0
# ...................
# RT @disco2man: Hairy cell leukaemia
# Head and neck cancer
# Hodgkin lymphoma
# Kidney cancer
# Laryngeal cancer
# Leukaemia
# Liver cancer
# Lung cancer…
#
# the list of words ['rt', 'hairy', 'cell', 'leukaemia', 'head', 'and', 'neck', 'cancer', 'hodgkin', 'lymphoma', 'kidney', 'cancer', 'laryngeal', 'cancer', 'leukaemia', 'liver', 'cancer', 'lung', 'cancer\xe2\x80\xa6']
# hashtags referenced []
# twitter users mentioned ['disco2man']
# URLs []
# AFINN sentiment score -4
# ............................
# description: HR676 Universal Health Care for ALL if you dont vote 4 #HR676 you are going straight to HELL
# followers_count: 2232
# friends_count: 2430
# favourites_count: 15793
# location: Deadwood ,Purgatory
# time_zone: Saskatchewan
# screen_name: Fochik
# name: TheRealAbbyNormal
# ====================================================================================
#
# the actual text of results[32]['text']
# retweet_count  = 5
# favorite_count = 0
# ...................
# RT @ShockingFactsz: Lung cancer was how the cigarette company Marlboro’s first owner died.
#
# the list of words ['rt', 'lung', 'cancer', 'was', 'how', 'the', 'cigarette', 'company', 'marlboro\xe2\x80\x99s', 'first', 'owner', 'died.']
# hashtags referenced []
# twitter users mentioned ['shockingfactsz']
# URLs []
# AFINN sentiment score -1
# ............................
# description: Am an aspiring sport broadcaster,Sports is my passion. I support the best team in the world @FcBarcelona. Am a CSC Student.   #TeamNadal #RihannaNavy
# followers_count: 857
# friends_count: 428
# favourites_count: 48
# location: Lagos,Nigeria.
# time_zone: Madrid
# screen_name: sleekshady22
# name: MUCHO ANIMO NEYMAR
# ====================================================================================
#
# the actual text of results[33]['text']
# retweet_count  = 5
# favorite_count = 0
# ...................
# RT @ShockingFactsz: Lung cancer was how the cigarette company Marlboro’s first owner died.
#
# the list of words ['rt', 'lung', 'cancer', 'was', 'how', 'the', 'cigarette', 'company', 'marlboro\xe2\x80\x99s', 'first', 'owner', 'died.']
# hashtags referenced []
# twitter users mentioned ['shockingfactsz']
# URLs []
# AFINN sentiment score -1
# ............................
# description: I am a huge fan of all things Rob and Kristen. I believe in Rob and Kristen together and have never stopped believing in them.
# followers_count: 82
# friends_count: 104
# favourites_count: 1651
# location: Canada
# time_zone: None
# screen_name: Rkstthomas
# name: Wendy Fleming
# ====================================================================================
#
# the actual text of results[34]['text']
# retweet_count  = 5
# favorite_count = 0
# ...................
# RT @ShockingFactsz: Lung cancer was how the cigarette company Marlboro’s first owner died.
#
# the list of words ['rt', 'lung', 'cancer', 'was', 'how', 'the', 'cigarette', 'company', 'marlboro\xe2\x80\x99s', 'first', 'owner', 'died.']
# hashtags referenced []
# twitter users mentioned ['shockingfactsz']
# URLs []
# AFINN sentiment score -1
# ............................
# description: #teamMESSI #teamARGENTINA #teamBARCA #MUSICA life long fan of LEO MESSI,BOJAN's twin brother, AGUERO's cousin, Nalhie's cup of joy
# followers_count: 944
# friends_count: 1015
# favourites_count: 1221
# location:
# time_zone: West Central Africa
# screen_name: Kunlemessi
# name: ARGENTIGERIAN
# ====================================================================================
#
# the actual text of results[35]['text']
# retweet_count  = 5
# favorite_count = 0
# ...................
# Lung cancer was how the cigarette company Marlboro’s first owner died.
#
# the list of words ['lung', 'cancer', 'was', 'how', 'the', 'cigarette', 'company', 'marlboro\xe2\x80\x99s', 'first', 'owner', 'died.']
# hashtags referenced []
# twitter users mentioned []
# URLs []
# AFINN sentiment score -1
# ............................
# description: These are the facts that will shock you all!
# followers_count: 4102
# friends_count: 2432
# favourites_count: 0
# location:
# time_zone: Baghdad
# screen_name: ShockingFactsz
# name: Shocking Facts
# ====================================================================================
#
# the actual text of results[36]['text']
# retweet_count  = 7
# favorite_count = 0
# ...................
# RT @BasedGarby: Oh you smoke cigs? How that lung cancer feeling?
#
# the list of words ['rt', 'oh', 'you', 'smoke', 'cigs?', 'how', 'that', 'lung', 'cancer', 'feeling?']
# hashtags referenced []
# twitter users mentioned ['basedgarby']
# URLs []
# AFINN sentiment score -1
# ............................
# description: May I take your hat sir?
# followers_count: 647
# friends_count: 764
# favourites_count: 6030
# location: Central Florida
# time_zone: Atlantic Time (Canada)
# screen_name: _rizzzo_
# name: Jarod Meadows
# ====================================================================================
#
# the actual text of results[37]['text']
# retweet_count  = 4
# favorite_count = 0
# ...................
# RT @DrFrankBeard: Plunge in smoking attributed to plain packaging - likened to finding a vaccine against lung cancer http://t.co/HkoX92g4OC…
# the list of words ['rt', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging', 'likened', 'to', 'finding', 'a', 'vaccine', 'against', 'lung', 'cancer']
# hashtags referenced []
# twitter users mentioned ['drfrankbeard']
# URLs ['http://t.co/hkox92g4oc']
# AFINN sentiment score -1
# ............................
# description: public health physician trainee, global health, gender equity, development, health equity –passionate about right to health and all things ocean. tweets my own.
# followers_count: 191
# friends_count: 376
# favourites_count: 366
# location: Sydney, Australia
# time_zone: Hawaii
# screen_name: crbstee
# name: catherine b steel
# ====================================================================================
#
# the actual text of results[38]['text']
# retweet_count  = 7
# favorite_count = 0
# ...................
# RT @BasedGarby: Oh you smoke cigs? How that lung cancer feeling?
#
# the list of words ['rt', 'oh', 'you', 'smoke', 'cigs?', 'how', 'that', 'lung', 'cancer', 'feeling?']
# hashtags referenced []
# twitter users mentioned ['basedgarby']
# URLs []
# AFINN sentiment score -1
# ............................
# description: just your typical piece of shit.
# followers_count: 848
# friends_count: 224
# favourites_count: 3083
# location: Florida
# time_zone: Eastern Time (US & Canada)
# screen_name: roly_aT
# name: TRIPLE-T
# ====================================================================================
#
# the actual text of results[39]['text']
# retweet_count  = 7
# favorite_count = 0
# ...................
# RT @BasedGarby: Oh you smoke cigs? How that lung cancer feeling?
#
# the list of words ['rt', 'oh', 'you', 'smoke', 'cigs?', 'how', 'that', 'lung', 'cancer', 'feeling?']
# hashtags referenced []
# twitter users mentioned ['basedgarby']
# URLs []
# AFINN sentiment score -1
# ............................
# description:
# followers_count: 404
# friends_count: 198
# favourites_count: 4137
# location:
# time_zone: Eastern Time (US & Canada)
# screen_name: daanabby
# name: Queen D
# ====================================================================================
#
# the actual text of results[40]['text']
# retweet_count  = 7
# favorite_count = 0
# ...................
# RT @BasedGarby: Oh you smoke cigs? How that lung cancer feeling?
#
# the list of words ['rt', 'oh', 'you', 'smoke', 'cigs?', 'how', 'that', 'lung', 'cancer', 'feeling?']
# hashtags referenced []
# twitter users mentioned ['basedgarby']
# URLs []
# AFINN sentiment score -1
# ............................
# description: Stay pretty. Be educated. Dress well. Get money.
# followers_count: 153
# friends_count: 142
# favourites_count: 826
# location:
# time_zone: Eastern Time (US & Canada)
# screen_name: kaicee_reece
# name: Kaicee™
# ====================================================================================
#
# the actual text of results[41]['text']
# retweet_count  = 7
# favorite_count = 0
# ...................
# RT @BasedGarby: Oh you smoke cigs? How that lung cancer feeling?
#
# the list of words ['rt', 'oh', 'you', 'smoke', 'cigs?', 'how', 'that', 'lung', 'cancer', 'feeling?']
# hashtags referenced []
# twitter users mentioned ['basedgarby']
# URLs []
# AFINN sentiment score -1
# ............................
# description: When in doubt, twerk it out✨
# followers_count: 306
# friends_count: 235
# favourites_count: 8316
# location:
# time_zone: None
# screen_name: GraceRikki
# name: Rikkkkki♡
# ====================================================================================
#
# the actual text of results[42]['text']
# retweet_count  = 7
# favorite_count = 0
# ...................
# RT @BasedGarby: Oh you smoke cigs? How that lung cancer feeling?
#
# the list of words ['rt', 'oh', 'you', 'smoke', 'cigs?', 'how', 'that', 'lung', 'cancer', 'feeling?']
# hashtags referenced []
# twitter users mentioned ['basedgarby']
# URLs []
# AFINN sentiment score -1
# ............................
# description: My fathers keeper.
# followers_count: 599
# friends_count: 215
# favourites_count: 6
# location:
# time_zone: Pacific Time (US & Canada)
# screen_name: thecalmbreeze
# name: Sicily ∞
# ====================================================================================
#
# the actual text of results[43]['text']
# retweet_count  = 7
# favorite_count = 0
# ...................
# RT @BasedGarby: Oh you smoke cigs? How that lung cancer feeling?
#
# the list of words ['rt', 'oh', 'you', 'smoke', 'cigs?', 'how', 'that', 'lung', 'cancer', 'feeling?']
# hashtags referenced []
# twitter users mentioned ['basedgarby']
# URLs []
# AFINN sentiment score -1
# ............................
# description: she doesn't even go here
# followers_count: 852
# friends_count: 621
# favourites_count: 18267
# location: florida
# time_zone: Quito
# screen_name: PrincessCiara13
# name: c money
# ====================================================================================
#
# the actual text of results[44]['text']
# retweet_count  = 7
# favorite_count = 6
# ...................
# Oh you smoke cigs? How that lung cancer feeling?
#
# the list of words ['oh', 'you', 'smoke', 'cigs?', 'how', 'that', 'lung', 'cancer', 'feeling?']
# hashtags referenced []
# twitter users mentioned []
# URLs []
# AFINN sentiment score -1
# ............................
# description: All Hail Yung Garby the $nacklord #forevershitty
# followers_count: 664
# friends_count: 478
# favourites_count: 2895
# location: 2009
# time_zone: Quito
# screen_name: BasedGarby
# name: $NACKLORD GARBY
# ====================================================================================
#
# the actual text of results[45]['text']
# retweet_count  = 11
# favorite_count = 0
# ...................
# RT @BabaRamDass: Question: I’ve had a lot of loss in my life and my husband has lung cancer and I’m facing more loss in my future...http://…
#
# the list of words ['rt', 'question:', 'i\xe2\x80\x99ve', 'had', 'a', 'lot', 'of', 'loss', 'in', 'my', 'life', 'and', 'my', 'husband', 'has', 'lung', 'cancer', 'and', 'i\xe2\x80\x99m', 'facing', 'more', 'loss', 'in', 'my', 'future...http://\xe2\x80\xa6']
# hashtags referenced []
# twitter users mentioned ['babaramdass']
# URLs []
# AFINN sentiment score -7
# ............................
# description: I've been to paradise, but I've never been to me.
# followers_count: 99
# friends_count: 185
# favourites_count: 57
# location: Tir Falamh
# time_zone: None
# screen_name: jsnowdendavies
# name: Zapiekanka
# ====================================================================================
#
# the actual text of results[46]['text']
# retweet_count  = 9
# favorite_count = 0
# ...................
# RT @broadinstitute: Study identifies novel genomic changes in the most common type of lung cancer: TCGA finds mutations in a key c... http:…
#
# the list of words ['rt', 'study', 'identifies', 'novel', 'genomic', 'changes', 'in', 'the', 'most', 'common', 'type', 'of', 'lung', 'cancer:', 'tcga', 'finds', 'mutations', 'in', 'a', 'key', 'c...', 'http:\xe2\x80\xa6']
# hashtags referenced []
# twitter users mentioned ['broadinstitute']
# URLs []
# AFINN sentiment score 2
# ............................
# description: MIT digital diplomas: 7.00x & 7.QBWx. Blog: Ethics, Health & Death 2.0 - Genomics & machine learning. From Broad Institute to Broadway?
# followers_count: 1996
# friends_count: 2114
# favourites_count: 9552
# location: Genomic Entertainment
# time_zone: Amsterdam
# screen_name: cathcoste
# name: CATHERINE COSTE
# ====================================================================================
#
# the actual text of results[47]['text']
# retweet_count  = 14
# favorite_count = 0
# ...................
# RT @SUMedicine: "As a young #lungcancer patient, I had to find my own path" how one patient fought a stage IV diagnosis w/ full force http:…
#
# the list of words ['rt', '"as', 'a', 'young', 'patient,', 'i', 'had', 'to', 'find', 'my', 'own', 'path"', 'how', 'one', 'patient', 'fought', 'a', 'stage', 'iv', 'diagnosis', 'w/', 'full', 'force', 'http:\xe2\x80\xa6']
# hashtags referenced ['lungcancer']
# twitter users mentioned ['sumedicine']
# URLs []
# AFINN sentiment score 0
# ............................
# description: Using data to highlight great Stanford University communication. From @measuredvoice
# http://t.co/VmMv8Z6co9
# followers_count: 99
# friends_count: 38
# favourites_count: 41
# location:
# time_zone: Pacific Time (US & Canada)
# screen_name: stanfordtweet
# name: Stanford Tweets
# ====================================================================================
#
# the actual text of results[48]['text']
# retweet_count  = 4
# favorite_count = 0
# ...................
# RT @DrFrankBeard: Plunge in smoking attributed to plain packaging - likened to finding a vaccine against lung cancer http://t.co/HkoX92g4OC…
# the list of words ['rt', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging', 'likened', 'to', 'finding', 'a', 'vaccine', 'against', 'lung', 'cancer']
# hashtags referenced []
# twitter users mentioned ['drfrankbeard']
# URLs ['http://t.co/hkox92g4oc']
# AFINN sentiment score -1
# ............................
# description: Public Health Researcher Monash Uni | Qual & Quant Research | Churches & Health Promotion | Chronic Diseases | Ayton & Joss Consulting | Wife | Mini Dach Owner
# followers_count: 409
# friends_count: 976
# favourites_count: 1204
# location: Melbourne
# time_zone: Melbourne
# screen_name: darsh_deva
# name: Dr Darshini Ayton
# ====================================================================================
#
# the actual text of results[49]['text']
# retweet_count  = 10
# favorite_count = 0
# ...................
# RT @theNCI: The #LungMAP trial will profile tumors to match patients &amp; treatments: http://t.co/aJ6Rmw52m1 #cancer #genomics #lcsm http://t.…
#
# the list of words ['rt', 'the', 'trial', 'will', 'profile', 'tumors', 'to', 'match', 'patients', 'treatments:', '.\xe2\x80\xa6']
# hashtags referenced ['lungmap', 'cancer', 'genomics', 'lcsm']
# twitter users mentioned ['thenci']
# URLs ['http://t.co/aj6rmw52m1', 'http://t']
# AFINN sentiment score 0
# ............................
# description:
# followers_count: 89
# friends_count: 257
# favourites_count: 2034
# location:
# time_zone: None
# screen_name: StefaniaArciell
# name: Stefania Arciello
# ====================================================================================
#
# the actual text of results[50]['text']
# retweet_count  = 10
# favorite_count = 0
# ...................
# RT @theNCI: The #LungMAP trial will profile tumors to match patients &amp; treatments: http://t.co/aJ6Rmw52m1 #cancer #genomics #lcsm http://t.…
#
# the list of words ['rt', 'the', 'trial', 'will', 'profile', 'tumors', 'to', 'match', 'patients', 'treatments:', '.\xe2\x80\xa6']
# hashtags referenced ['lungmap', 'cancer', 'genomics', 'lcsm']
# twitter users mentioned ['thenci']
# URLs ['http://t.co/aj6rmw52m1', 'http://t']
# AFINN sentiment score 0
# ............................
# description: The North American Association of Central Cancer Registries
# followers_count: 247
# friends_count: 33
# favourites_count: 1
# location: Springfield, IL
# time_zone: Central Time (US & Canada)
# screen_name: NAACCR
# name: NAACCR, Inc.
# ====================================================================================
#
# the actual text of results[51]['text']
# retweet_count  = 4
# favorite_count = 0
# ...................
# RT @DrFrankBeard: Plunge in smoking attributed to plain packaging - likened to finding a vaccine against lung cancer http://t.co/HkoX92g4OC…
#
# the list of words ['rt', 'plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging', 'likened', 'to', 'finding', 'a', 'vaccine', 'against', 'lung', 'cancer']
# hashtags referenced []
# twitter users mentioned ['drfrankbeard']
# URLs ['http://t.co/hkox92g4oc']
# AFINN sentiment score -1
# ............................
# description: Shadow Minister for Health, Federal Member for Ballarat
# followers_count: 7213
# friends_count: 495
# favourites_count: 22
# location: Victoria, Australia
# time_zone: Melbourne
# screen_name: CatherineKingMP
# name: Catherine King MP
# ====================================================================================
#
# the actual text of results[52]['text']
# retweet_count  = 55
# favorite_count = 0
# ...................
# RT @SmokefreeWomen: The most common cancer women die of? Not breast cancer. Lung cancer. More women in the U.S. die from lung cancer than a…
#
# the list of words ['rt', 'the', 'most', 'common', 'cancer', 'women', 'die', 'of?', 'not', 'breast', 'cancer.', 'lung', 'cancer.', 'more', 'women', 'in', 'the', 'u.s.', 'die', 'from', 'lung', 'cancer', 'than', 'a\xe2\x80\xa6']
# hashtags referenced []
# twitter users mentioned ['smokefreewomen']
# URLs []
# AFINN sentiment score -8
# ............................
# description:
# followers_count: 47
# friends_count: 100
# favourites_count: 1
# location: Florida
# time_zone: Eastern Time (US & Canada)
# screen_name: ARROWLBTHealth
# name: ARROW
# ====================================================================================
#
# the actual text of results[53]['text']
# retweet_count  = 4
# favorite_count = 1
# ...................
# Plunge in smoking attributed to plain packaging - likened to finding a vaccine against lung cancer http://t.co/HkoX92g4OC via @smh
#
# the list of words ['plunge', 'in', 'smoking', 'attributed', 'to', 'plain', 'packaging', 'likened', 'to', 'finding', 'a', 'vaccine', 'against', 'lung', 'cancer', 'via']
# hashtags referenced []
# twitter users mentioned ['smh']
# URLs ['http://t.co/hkox92g4oc']
# AFINN sentiment score -1
# ............................
# description: Public health physician working in immunisation and VPD policy/surveillance/research. Ex-GP. Interested in public health, media, culture. Own opinions.
# followers_count: 372
# friends_count: 408
# favourites_count: 377
# location: Sydney, Australia
# time_zone: None
# screen_name: DrFrankBeard
# name: Frank Beard
# ====================================================================================
#
# the actual text of results[54]['text']
# retweet_count  = 10
# favorite_count = 0
# ...................
# RT @theNCI: The #LungMAP trial will profile tumors to match patients &amp; treatments: http://t.co/aJ6Rmw52m1 #cancer #genomics #lcsm http://t.…
#
# the list of words ['rt', 'the', 'trial', 'will', 'profile', 'tumors', 'to', 'match', 'patients', 'treatments:', '.\xe2\x80\xa6']
# hashtags referenced ['lungmap', 'cancer', 'genomics', 'lcsm']
# twitter users mentioned ['thenci']
# URLs ['http://t.co/aj6rmw52m1', 'http://t']
# AFINN sentiment score 0
# ............................
# description: On March 7, 2013, I passed away from an orphan cancer. My legacy to Pay It Forward carries on with my team in the Enbridge Ride to Conquer Cancer.
# followers_count: 4
# friends_count: 22
# favourites_count: 0
# location: Cochrane, Alberta, Canada
# time_zone: None
# screen_name: JarridsTeam
# name: Jarrid Rich
# ====================================================================================
#
# the actual text of results[55]['text']
# retweet_count  = 5
# favorite_count = 0
# ...................
# RT @TheImproperMag: Texas man fights terminal lung #cancer without chemo using #LCHF #ketogenic diet and #BJJ http://t.co/28v9c0EOwU http:/…
#
# the list of words ['rt', 'texas', 'man', 'fights', 'terminal', 'lung', 'without', 'chemo', 'using', 'diet', 'and', 'http:/\xe2\x80\xa6']
# hashtags referenced ['cancer', 'lchf', 'ketogenic', 'bjj']
# twitter users mentioned ['theimpropermag']
# URLs ['http://t.co/28v9c0eowu']
# AFINN sentiment score 0
# ............................
# description: http://t.co/DIRQuYGI5s
# #w2muscle #w2supps #w2gains #w2health #w2deals #w2stacks #fitness #investing #economics
# followers_count: 3787
# friends_count: 3830
# favourites_count: 6720
# location: Midwest
# time_zone: None
# screen_name: whey2muscle
# name: Michael T. Henry
# ====================================================================================
# twitter_functions.py:302: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if word in ['.',':','!',',',';',"-","-","?",'\xe2\x80\xa6',"!","&amp;","|"]: continue

# %% [markdown]
# # Let's do a quick lexical analysis of these tweets

# %% [markdown]
# ####Step 1: Collect all the tweets in one string
#
# Note: the AFINN score will be for the entire string, which may or may not be helpful

# %%
tweets = ""
for i in range(num_tweets):
    tweets = tweets + " " + results[i]['text']

words, hashes, users, urls, AFINN_score = parse_tweet_text(tweets, AFINN=True)

print "AFINN sentiment score %d"%AFINN_score
# Out:
# AFINN sentiment score 13

# %% [markdown]
# ####Step 2: Remove the stop words
#
# Note: English stop words won't help in Espanish

# %%
from nltk.corpus import stopwords

stop = stopwords.words('english')
stop.append("it's")
stop.append('w/')

filtered_word_list = [word for word in words if word not in stop]
filtered_word_set  = set(filtered_word_list)

print "%d  total words"%len(filtered_word_list)
print "%d unique words"%len(filtered_word_set)
# Out:
# 660  total words
# 111 unique words

# %% [markdown]
# ####Step 3: Show the top 10 of each entity type
#
# Note: 'rt' means retweet and it's very common, but you may not consider it a word

# %%
from collections import Counter
from prettytable import PrettyTable

for label, data in (('Word', filtered_word_list), 
                    ('Senders', senders), 
                    ('Users Mentioned', users),
                    ('Hashtag', hashes),
                    ('URL', urls)):
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print pt
# Out:
# +------------+-------+
# | Word       | Count |
# +------------+-------+
# | lung       |    53 |
# | rt         |    52 |
# | vaccine    |    30 |
# | attributed |    30 |
# | smoking    |    30 |
# | plain      |    30 |
# | plunge     |    30 |
# | finding    |    30 |
# | cancer     |    27 |
# | like       |    25 |
# +------------+-------+
# +-------------------+-------+
# | Senders           | Count |
# +-------------------+-------+
# | Geoffrey Payne    |     2 |
# | Maria Matthews    |     1 |
# | Madam Dee Baker   |     1 |
# | eric hardcastle   |     1 |
# | Joshua McKinnon   |     1 |
# | TheRealAbbyNormal |     1 |
# | Stanford Tweets   |     1 |
# | jayda.            |     1 |
# | Susan Mackay      |     1 |
# | Stefania Arciello |     1 |
# +-------------------+-------+
# +-----------------+-------+
# | Users Mentioned | Count |
# +-----------------+-------+
# | tanya_plibersek |    24 |
# | basedgarby      |     7 |
# | shockingfactsz  |     5 |
# | thenci          |     4 |
# | drfrankbeard    |     4 |
# | rosaaaa05       |     2 |
# | smh             |     1 |
# | smokefreewomen  |     1 |
# | theimpropermag  |     1 |
# | babaramdass     |     1 |
# +-----------------+-------+
# +------------+-------+
# | Hashtag    | Count |
# +------------+-------+
# | cancer     |     4 |
# | genomics   |     3 |
# | lungmap    |     3 |
# | lcsm       |     3 |
# | bjj        |     1 |
# | ketogenic  |     1 |
# | lungcancer |     1 |
# | lchf       |     1 |
# +------------+-------+
# +------------------------+-------+
# | URL                    | Count |
# +------------------------+-------+
# | http://t.co/hkox92g4oc |     5 |
# | http://t.co/aj6rmw52m1 |     3 |
# | http://t               |     3 |
# | http://t.co/28v9c0eowu |     1 |
# | http://t.co/tuupqzstgo |     1 |
# | http://t.co/qz0ar8vq6d |     1 |
# +------------------------+-------+

# %% [markdown]
# ####Step 4: Lexical Diversity

# %%
from twitter_functions import lexical_diversity, average_words

print "Lexical Diversity"
print "words  %0.2f"%lexical_diversity(set(words), words) # words not filtered_word_list
print "hashes %0.2f"%lexical_diversity(set(hashes), hashes)
print "users  %0.2f"%lexical_diversity(set(users), users)
print "urls   %0.2f"%lexical_diversity(set(urls), urls)

print "\nAverage per tweet"
print "words           %0.2f"%average_words(words, num_tweets)
print "filtered words  %0.2f"%average_words(filtered_word_list, num_tweets)
print "hashes          %0.2f"%average_words(hashes, num_tweets)
print "users           %0.2f"%average_words(users, num_tweets)
print "urls            %0.2f"%average_words(urls, num_tweets)
# Out:
# Lexical Diversity
# words  0.15
# hashes 0.47
# users  0.25
# urls   0.43
#
# Average per tweet
# words           16.36
# filtered words  11.79
# hashes          0.30
# users           0.95
# urls            0.25

# %% [markdown]
# ####Step 5: Can't finish without a word cloud, right?
#
# Note 1: foreign-language codes often cause this to fail.
#
# Note 2: the lexical density determines the look of the result: a few words in a mass of many infrequent words makes for a more attractive picture. Playing with the numerical parameter to num_tags also has an effect.

# %%
from pytagcloud import create_tag_image, make_tags
import IPython.display

# 'rt' is very common and useless
filter_ex_rt = list(filtered_word_list)
while 'rt' in filter_ex_rt: filter_ex_rt.remove('rt')

for item in [filter_ex_rt]:
    c = Counter(item)

num_tags = min(150, len(c.most_common())-1)
tags     = make_tags(c.most_common()[:num_tags], maxsize=120)

create_tag_image(tags, 'wordcloud.png', size=(900,900), fontname='Lobster' )

IPython.display.display(IPython.display.Image(filename='wordcloud.png'))
